# %% [markdown]
# ## Workflow to Generate Data Using ReQUESTA

# %%
from pathlib import Path
import re
import pandas as pd
from src.general import get_files_in_directory, read_text_file
from src.workflow import question_generation_workflow

async def  generate_mcqs(subject: str, directory_path: str, fact: int, inference: int, main_idea: int, model: str, output_directory: str) -> pd.DataFrame:
    """
    Generate MCQs from text files in a specified directory and save them to a CSV file.

    Args:
        subject (str): The subject name.
        directory_path (str): Path to the directory containing text files.
        fact (int): Number of fact-based questions to generate.
        inference (int): Number of inference-based questions to generate.
        main_idea (int): Number of main idea-based questions to generate.
        model (str): The model to use for question generation.
        output_directory (str): Directory to save the output CSV file.

    Returns:
        pd.DataFrame: DataFrame containing the generated MCQs.
    """
    # Convert directory paths to Path objects
    directory_path = Path(directory_path)
    output_directory = Path(output_directory)

    # Get files from the specified directory
    files = get_files_in_directory(directory_path)

    # Initialize lists to store data
    subjects = []
    chapter_names = []
    section_names = []
    question_types = []
    mcq_list = []
    mcq_answer_list = []

    total_files = len(files)

    for index, afile in enumerate(files):
        print(f"__________________________________________Processing file {index} of {total_files}: {afile}___________________________________________________")
        # Get chapter and section names from the file name
        file_path = Path(afile)
        relative_file_name = file_path.relative_to(directory_path)
        file_stem = relative_file_name.stem

        try:
            chapter_name, section_name = file_stem.split('.')
        except ValueError:
            raise ValueError(f"Filename format is incorrect: '{file_stem}'. Expected format 'X.Y.txt'")

        # Read the file content
        atext = read_text_file(afile)

        # Generate MCQs using the question generation workflow
        mcqs = await question_generation_workflow(atext, fact=fact, inference=inference, main_idea=main_idea, model=model)
        
        for mcq in mcqs:
            amcq = mcq.get('mcq', 'No MCQ generated')
            amcq_answer = mcq.get('mcq_answer', 'No MCQ answer generated')

            # Remove the 'Q1: ' from the mcq and mcq_answer
            amcq = re.sub(r'^Q\d+: ', '', amcq)
            amcq_answer = re.sub(r'^Q\d+: ', '', amcq_answer)

            question_type = mcq.get("question_type", "unknown")

            # Append the results to the list
            question_types.append(question_type)
            mcq_list.append(amcq)
            mcq_answer_list.append(amcq_answer)

            chapter_names.append(chapter_name)
            section_names.append(section_name)
            subjects.append(subject)

        # Create a DataFrame to store the results
        mcq_data = {
            'Subject': subjects,
            'Chapter': chapter_names,
            'Section': section_names,
            'Question_type': question_types,
            'Question': mcq_list,
            'Answer': mcq_answer_list
        }

        mcq_df = pd.DataFrame(mcq_data)

        # Ensure the output directory exists
        output_directory = Path(output_directory)
        output_directory.mkdir(parents=True, exist_ok=True)
        output_file = output_directory / f'{subject}_mcqs_{file_stem}.csv'

        # Save the DataFrame to a CSV file
        mcq_df.to_csv(output_file, index=False)

    return mcq_df

# %%
import re
from pathlib import Path
import pandas as pd
from src.general import get_files_in_directory, read_text_file

def extract_texts(subject: str, directory_path: str, output_directory: str) -> pd.DataFrame:
    """
    Extract texts from files in a specified directory, calculate word count, and save them to a CSV file.

    Args:
        subject (str): The subject name.
        directory_path (str): Path to the directory containing text files.
        output_directory (str): Directory to save the output CSV file.

    Returns:
        pd.DataFrame: DataFrame containing the extracted texts and their word counts.
    """
    # Convert directory paths to Path objects
    directory_path = Path(directory_path)
    output_directory = Path(output_directory)

    # Get files from the specified directory
    files = get_files_in_directory(directory_path)

    # Initialize lists to store data
    subjects = []
    chapter_names = []
    section_names = []
    texts = []
    word_counts = []

    for afile in files:
        # Get chapter and section names from the file name
        file_path = Path(afile)
        relative_file_name = file_path.relative_to(directory_path)
        file_stem = relative_file_name.stem

        try:
            chapter_name, section_name = file_stem.split('.')
        except ValueError:
            raise ValueError(f"Filename format is incorrect: '{file_stem}'. Expected format 'X.Y.txt'")

        # Read the file content
        atext = read_text_file(afile)

        # Replace multiple newline characters with a single space
        atext = re.sub(r'\n+', ' ', atext)

        # Calculate word count
        word_count = len(atext.split())

        # Append the results to the list
        subjects.append(subject)
        chapter_names.append(chapter_name)
        section_names.append(section_name)
        texts.append(atext)
        word_counts.append(word_count)

    # Create a DataFrame to store the results
    text_data = {
        'Subject': subjects,
        'Chapter': chapter_names,
        'Section': section_names,
        'Text': texts,
        'Word Count': word_counts
    }

    text_df = pd.DataFrame(text_data)

    # Ensure the output directory exists
    output_directory.mkdir(parents=True, exist_ok=True)
    output_file = output_directory / f'{subject}_texts.csv'

    # Save the DataFrame to a CSV file
    text_df.to_csv(output_file, index=False)

    return text_df

# %%
subject = "History"
directory_path = '../data/History'
output_directory = '../output/mcqs'


mcq_df = await generate_mcqs(
    subject=subject,
    directory_path=directory_path,
    fact=0,
    inference=0,
    main_idea=1,    
    model='gpt-4o',  
    output_directory=output_directory,
)
# Out:
# INFO:root:Workflow started at: 2025-07-23 16:55:32.749039
# INFO:root:Invocation ID: 0b60415f-84b1-4a62-9a4f-ab21c1dff8af
# __________________________________________Processing file 0 of 20: ..\data\History\1.3.txt___________________________________________________
# INFO:root:Text is now successfully chunked into smaller parts.
# INFO:root:Table 'plan_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\n  You are an experienced college instructor specializing in developing reading comprehension questions to evaluate students\' understanding of academic texts, such as textbook chapters and academic articles. You excel at identifying and selecting key facts and inferences from these texts for question development.\n\n[TASK]:\n  Your task is to summarize the academic text provided by the user and select the specified number of facts and inferences as requested by the user following the guidelines below. \n\n[Guidelines]\n  Step1: Summarize the text \n  The text is divided into chunks (as indicated by the html tags such as <chunk1></chunk1>). Summarize the content within each chunk, maintaining the chunk tags in your summary.\n\n  Step2: Identify key facts and/or inferences\n  Depending on the user’s requests, create a list of key facts and/or inferences from the academic text. The number of facts or inferences generated in this step can be more than what the user requests. \n  \n  Read the definitions below to better understand what key facts and inferences are:\n  \n  ** Key Facts**\n  Key facts are explicit pieces of information stated directly in the text. They usually reflect the main ideas, supporting details, definitions, results, or statistics that are important for understanding the author’s argument or findings.\n \n  ** Key Inferences**\n  Key inferences are logical conclusions that a reader can draw from the information in the text, even though they are not directly stated. Inferences require the reader to interpret, analyze, or synthesize information to understand implications, underlying meanings, or cause-effect relationships.\n  Characteristics:\n  - Require higher-order thinking (interpretive or inferential comprehension)\n  - Often answer the questions: why, what does this suggest, what can be concluded, what would likely happen if...\n  Example (from a sociology article):\n  "In communities with high income inequality, researchers found lower levels of trust among residents and reduced participation in civic activities."\n  Key inference: High income inequality may contribute to weakened social cohesion.\n\n  key inferences may emerge from synthesizing ideas spread across multiple sentences or paragraphs. These inferences require readers to connect concepts that are not directly adjacent in the text.\n  Example (from a Psychology Text):\n  chunk1: "...Studies show that securely attached infants tend to be more socially competent and exhibit fewer behavioral problems later in life..."\n  chunk5: "...Longitudinal research indicates that early childhood experiences with caregivers shape patterns of emotion regulation, social skills, and even academic performance into adolescence and adulthood..."\n  Key inference: Children who experience secure attachment and authoritative parenting early in life are more likely to develop strong emotional and social skills that persist into adolescence and adulthood.\n\n  **Principles for Identifying Key Facts and Inferences**\n    - Focus on Central Ideas: Identify the main argument, thesis, or purpose of the text.\n    - Highlight Supporting Information: Look for facts, evidence, definitions, or examples that directly support the main ideas.\n    - Pay Attention to Logical Relationships: Note cause-effect, comparison, contrast, and sequence relationships that organize the information.\n    - Recognize Implied Meaning: Infer what the author suggests but does not say directly—such as assumptions, tone, or implications.\n    - Ignore peripheral details: Exclude minor details (e.g., time, location), anecdotes, or examples that do not contribute significantly to the overall understanding of the text.\n    - Prioritize What’s Essential for Understanding: Choose facts and inferences that are crucial for grasping the ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E72711E0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000154E31BCB40> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E0F0C9D0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 23:55:41 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'7882'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'7889'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29995828'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'8ms'), (b'x-request-id', b'req_727ab5080b5cfff946a2aa6ebf6dbbe7'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=Bc.ZNSw.VBNvxf1JDycf_hGBCPRB723z.oTkF.0a3hE-1753314941-1.0.1.1-am2rH40sB01_iPFFdMBpbATK_4O7W85RGoe_Kc46HYzrxbUAf8yXdlPTapg5VV1x2su3hdb7MpGc6kjrDnGZ.FUHFFyDRgahmRlfhbY_iqA; path=/; expires=Thu, 24-Jul-25 00:25:41 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=L2PnVoxIfP31BrroPfg4HBZ.d2mITHrlY3rbspGTMaE-1753314941099-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963f1bfb592527c9-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'plan_metadata'.
# INFO:root:Plan generated successfully.
# INFO:root:Task list created successfully.
# INFO:root:Table 'mcq_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in writing multiple-choice questions to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYou are asked to write a main idea multiple-choice question based on an academic text summary provided by the user. \nFollow the guidelines in [GUIDELINES] to do exactly what you are instructed to do. \nNOTE: The user may provide an already generated question with evaluations, in which case you should revise the provided question based on the guidelines in [GUIDELINES] and the evaluations.\n\n[DEFINITION]\n**What are main idea questions?**\nMain idea questions assess a student\'s ability to identify the central point or primary argument of a text, passage, or section.\nInstead of focusing on specific details, examples, or minor points, these questions target the big picture — what the author is fundamentally trying to convey.\n\n[GUIDELINES]\nStep1: Carefully read the TEXT to understand its main idea.  \nStep2: Write a clear question stem. Typical stems include:\n  - "Which of the following best expresses the main idea of the passage?"\n  - "What is the primary purpose of the text?"\n  - "What is the central argument of the article?"\nStep3: Create the correct answer option. \n  - It should accurately reflect the main idea.\n  - It should be broad enough to cover the whole passage but specific enough to show real understanding.\n  - It should use words that are in the question sparingly.\nStep4: Write three plausible distractors. Good distractors often:\n  - Reflect common misconceptions or misinterpretations of the text.\n  - Sound reasonable to a student who only skimmed or misunderstood the text.\n  - Independent of each other and NOT variants of the correct answer.\n  - May reflect minor details from the text.\n  - Be similar in length, structure, tone, and complexity to the correct answer.\n  - Avoid deterministic words (e.g., solely, completely, always, never, purely, every, only) unless they accurately reflect real-world absolutes\n      Many test-takers are trained to spot absolute terms in options as red flags. Using these words in distractors can weaken the item’s ability to discriminate between high- and low-performing students unless they represent a plausible yet incorrect overstatement. Do not use them simply to make distractors sound wrong or extreme.\n      **Example**: \n      What is the main idea of the passage?\n        A). Urban planning always leads to positive outcomes for all residents.(Unrealistic exaggeration)\n        B). The sole purpose of urban planning is to increase green spaces in cities.(Overgeneralization)  \n        C). Urban planning must completely eliminate inequality to be effective. (Overly absolute)\n        D). Urban planning shapes city life and balances livability, equity, and sustainability. (correct answer)\n      Note: The distractors are easily dismissed by test-wise students, regardless of whether they understood the passage.\nStep5: Check the length of the correct answer. If the answer is longer than all the distractors, adjust it to be more concise while retaining its meaning.\nStep6: Self-critique the question and options to ensure clarity, accuracy, and relevance. \n  - Ensure that the question is clear and unambiguous.\n  - Ensure that the correct answer is clearly the best choice.\n  - Ensure that the distractors are plausible and relevant.\n  - Ensure that all the options are similar in length, structure, tone, and complexity.\n\n\nPrint out your reasoning BEFORE you print out the mutliple-choice main idea question. \n\nIMPORTANT: \n1) Wrap up the multiple-choice main idea question within <QUESTION></QUESTION> tags. The stem SHOULD be included in the <QUESTION> tags. Example:\n<QUESTION>What is ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E0FBA1D0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000154E0F4C740> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E702AE90>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 23:55:47 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'6125'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'6131'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29998593'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'2ms'), (b'x-request-id', b'req_4a7cd490b70e08b32692b30fc12ba903'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=aqMt.Px1h6p3hPFQgeov2bcrK1SD9Do.gAwNxcIzsvk-1753314947-1.0.1.1-r_kTqkQYyB4Ol5U3F2h_Nq2MpophZwfKW5mJKmVSzpX3tlcFCkyBTu9aDPYcnFlJrjhz0EGw1et8jYswzds3VbkMIDxLy7eXveFGo.qXp20; path=/; expires=Thu, 24-Jul-25 00:25:47 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=lWPqg0kCfd620.w2EOFE5h9KxKEEcnT8CPHoMDVVXI0-1753314947450-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963f1c2eaa7b27dd-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:src.mcq_generation:MCQ extracted on try 1.
# INFO:src.mcq_generation:Valid MCQ generated on try 1.
# INFO:src.mcq_generation:Answer extracted successfully.
# INFO:root:Table 'evaluation_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in evaluating the quality of multiple-choice questions generated to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to evaluate the quality of a multiple-choice question using a checklist in [CHECKLIST].\nThe user provides the multiple-choice question, the correct answer, the source text, and/or the contextual text.  \nProvide evaluation following the guidelines in [GUIDELINES].\nOutput your evaluation in the format specified in [OUTPUT FORMAT].\nself-critique your evalutation: \n  - the evaluation is based on the items in [CHECKLIST]. \n  - the evaluation follows the guidelines in [GUIDELINES].\n  - the output is in the format specified in [OUTPUT FORMAT].\n\n[CHECKLIST]\n**Content Accuracy and Quality Based on the Source Text**\n  •\tThere is only one correct answer; none of the distractors could apparently be interpreted as correct.\n  •\tDistractors are plausible misunderstandings.\n  •\tAll options are similar in tone, length, structure, and complexity, ensuring fairness and avoiding clues.\n  •\tDistractors do not use absolute terms (e.g., always, only, never, completely) unless such wording reflects a realistic but incorrect overgeneralization or misconception.\n  •\tDistractors are independent from each other and from the correct answer (i.e., not paraphrases or minor variations).\n**Language Quality**\n  •\tThe question stem has no unnecessary lead-ins like “According to the text,” “Based on the passage,” etc., unless needed for clarity, such as "According to conflict theory".\n  •\tThe question and options are clear, concise, and grammatically correct, free from redundancy and overly complex language.\n  •\tThe correct answer is not the longest among all the options.\n**Formatting Requirements**\n  •\tThe multiple-choice question should include the stem and four answer options starting with A), B), C), and D).:\n    What function did early exhibitors serve in the showcasing of movies in theaters?\n    \\nA) They determined the arrangement of different elements in the film program.\n    \\nB) They offered guidance to filmmakers regarding suitable movie content\n    \\nC) They frequently participated in live performances.\n    \\nD) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more line breaks in the question and answer options than shown in the example format.\n  •\tThe correct answer should includes both the correct option letter (e.g., A) ) and full answer text following this format:\n    D) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more space between the correct option letter and the answer text than shown in the example format.\n\n[GUIDELINES]\nStep1: Attempt to answer the multiple-choice question using the source text.\nStep2: Evaluate the question and answer choices using the checklist. \nStep3: Provide evaluation result based on the following rules. \n  - If all checklist criteria are met, output "YES".\n  - If any items under the **Content Accuracy and Quality Based on the Source Text** section is clearly and indisputably unmet, output: "NO".\n  **IMPORTANT**: Use "NO" only when there is clear and objective evidence that the criteria are not met. \n  - If all content-related criteria are met, but one or more items in either **Language Quality** or **Formatting Requirements** are not met, revise the question and/or the answer according to the criteria. Output "REVISED" followed by the revised version of the question and/or the revised answer. \n  **IMPORTANT**: Use "REVISED" only when problems are clearly and indisputably present. \nBe precise and cautious in your judgments. Do not ove ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E7251ED0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000154E31BE840> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E7253F10>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 23:55:49 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'1955'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'1962'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29998392'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'3ms'), (b'x-request-id', b'req_6495f9c7330116e601761e5cf32baec2'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=.7q0r6nmvm3gItbFliSX9iOY0FPflfh1T8HQ6nz6ZMo-1753314949-1.0.1.1-zmwPP4OTMWqYvNndgZBgae3ZO94FzVu2XX03dUtt9hFXV2epT8bP4xf83WL_5LG.WR6oSVmAJjoNrUdo4aX7rX2QrJyXPDQUkCONeNBanNM; path=/; expires=Thu, 24-Jul-25 00:25:49 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=Cz_zpiO_KWa9ABhClQlxP.rpOwItP8XxJ5_NJXGvJB0-1753314949823-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963f1c56381227d3-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'evaluation_metadata'.
# INFO:src.mcq_generation:Evaluation metadata generated successfully.
# INFO:src.mcq_generation:Evaluation passed successfully.
# INFO:root:Metadata inserted into 'mcq_metadata'.
# INFO:root:Questions generated successfully.
# INFO:root:MCQ options shuffled randomly.
# INFO:root:MCQ options shuffled successfully.
# INFO:root:Questions reformatted successfully.
# INFO:root:Table 'workflow_metadata' created or already exists.
# INFO:root:Metadata inserted into 'workflow_metadata'.
# INFO:root:Workflow metadata stored successfully.
# INFO:root:Workflow started at: 2025-07-23 16:55:49.934084
# INFO:root:Invocation ID: e0723fc9-678b-45a2-a50d-3ccd657a3859
# __________________________________________Processing file 1 of 20: ..\data\History\10.3.txt___________________________________________________
# INFO:root:Text is now successfully chunked into smaller parts.
# INFO:root:Table 'plan_metadata' created or already exists.
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\n  You are an experienced college instructor specializing in developing reading comprehension questions to evaluate students\' understanding of academic texts, such as textbook chapters and academic articles. You excel at identifying and selecting key facts and inferences from these texts for question development.\n\n[TASK]:\n  Your task is to summarize the academic text provided by the user and select the specified number of facts and inferences as requested by the user following the guidelines below. \n\n[Guidelines]\n  Step1: Summarize the text \n  The text is divided into chunks (as indicated by the html tags such as <chunk1></chunk1>). Summarize the content within each chunk, maintaining the chunk tags in your summary.\n\n  Step2: Identify key facts and/or inferences\n  Depending on the user’s requests, create a list of key facts and/or inferences from the academic text. The number of facts or inferences generated in this step can be more than what the user requests. \n  \n  Read the definitions below to better understand what key facts and inferences are:\n  \n  ** Key Facts**\n  Key facts are explicit pieces of information stated directly in the text. They usually reflect the main ideas, supporting details, definitions, results, or statistics that are important for understanding the author’s argument or findings.\n \n  ** Key Inferences**\n  Key inferences are logical conclusions that a reader can draw from the information in the text, even though they are not directly stated. Inferences require the reader to interpret, analyze, or synthesize information to understand implications, underlying meanings, or cause-effect relationships.\n  Characteristics:\n  - Require higher-order thinking (interpretive or inferential comprehension)\n  - Often answer the questions: why, what does this suggest, what can be concluded, what would likely happen if...\n  Example (from a sociology article):\n  "In communities with high income inequality, researchers found lower levels of trust among residents and reduced participation in civic activities."\n  Key inference: High income inequality may contribute to weakened social cohesion.\n\n  key inferences may emerge from synthesizing ideas spread across multiple sentences or paragraphs. These inferences require readers to connect concepts that are not directly adjacent in the text.\n  Example (from a Psychology Text):\n  chunk1: "...Studies show that securely attached infants tend to be more socially competent and exhibit fewer behavioral problems later in life..."\n  chunk5: "...Longitudinal research indicates that early childhood experiences with caregivers shape patterns of emotion regulation, social skills, and even academic performance into adolescence and adulthood..."\n  Key inference: Children who experience secure attachment and authoritative parenting early in life are more likely to develop strong emotional and social skills that persist into adolescence and adulthood.\n\n  **Principles for Identifying Key Facts and Inferences**\n    - Focus on Central Ideas: Identify the main argument, thesis, or purpose of the text.\n    - Highlight Supporting Information: Look for facts, evidence, definitions, or examples that directly support the main ideas.\n    - Pay Attention to Logical Relationships: Note cause-effect, comparison, contrast, and sequence relationships that organize the information.\n    - Recognize Implied Meaning: Infer what the author suggests but does not say directly—such as assumptions, tone, or implications.\n    - Ignore peripheral details: Exclude minor details (e.g., time, location), anecdotes, or examples that do not contribute significantly to the overall understanding of the text.\n    - Prioritize What’s Essential for Understanding: Choose facts and inferences that are crucial for grasping the ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E0FBA170>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000154E10A8740> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E0FBAE60>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 23:55:56 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'5853'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'5860'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29995248'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'9ms'), (b'x-request-id', b'req_7c1ef7135142e61d74d59df1c25eff27'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=xBpMoLy2_S21NO28jlsaVEpnX0FxZhn.Pb73ABqeDnk-1753314956-1.0.1.1-CpEORqZGm6t8LnaPlBJU76MMmuD1fFBjvUr59dohMeBHfa_b1IYn3qMxF5f06ifkILYDqEclmlYSBfzYgf6wxXHjcmOjqkC_d6gd.sPTiDY; path=/; expires=Thu, 24-Jul-25 00:25:56 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=fxUgY5KaK6NZvit3Z9JHvswXDGBspc2JxYvbOIK_gWs-1753314956259-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963f1c672d9927cf-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'plan_metadata'.
# INFO:root:Plan generated successfully.
# INFO:root:Task list created successfully.
# INFO:root:Table 'mcq_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in writing multiple-choice questions to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYou are asked to write a main idea multiple-choice question based on an academic text summary provided by the user. \nFollow the guidelines in [GUIDELINES] to do exactly what you are instructed to do. \nNOTE: The user may provide an already generated question with evaluations, in which case you should revise the provided question based on the guidelines in [GUIDELINES] and the evaluations.\n\n[DEFINITION]\n**What are main idea questions?**\nMain idea questions assess a student\'s ability to identify the central point or primary argument of a text, passage, or section.\nInstead of focusing on specific details, examples, or minor points, these questions target the big picture — what the author is fundamentally trying to convey.\n\n[GUIDELINES]\nStep1: Carefully read the TEXT to understand its main idea.  \nStep2: Write a clear question stem. Typical stems include:\n  - "Which of the following best expresses the main idea of the passage?"\n  - "What is the primary purpose of the text?"\n  - "What is the central argument of the article?"\nStep3: Create the correct answer option. \n  - It should accurately reflect the main idea.\n  - It should be broad enough to cover the whole passage but specific enough to show real understanding.\n  - It should use words that are in the question sparingly.\nStep4: Write three plausible distractors. Good distractors often:\n  - Reflect common misconceptions or misinterpretations of the text.\n  - Sound reasonable to a student who only skimmed or misunderstood the text.\n  - Independent of each other and NOT variants of the correct answer.\n  - May reflect minor details from the text.\n  - Be similar in length, structure, tone, and complexity to the correct answer.\n  - Avoid deterministic words (e.g., solely, completely, always, never, purely, every, only) unless they accurately reflect real-world absolutes\n      Many test-takers are trained to spot absolute terms in options as red flags. Using these words in distractors can weaken the item’s ability to discriminate between high- and low-performing students unless they represent a plausible yet incorrect overstatement. Do not use them simply to make distractors sound wrong or extreme.\n      **Example**: \n      What is the main idea of the passage?\n        A). Urban planning always leads to positive outcomes for all residents.(Unrealistic exaggeration)\n        B). The sole purpose of urban planning is to increase green spaces in cities.(Overgeneralization)  \n        C). Urban planning must completely eliminate inequality to be effective. (Overly absolute)\n        D). Urban planning shapes city life and balances livability, equity, and sustainability. (correct answer)\n      Note: The distractors are easily dismissed by test-wise students, regardless of whether they understood the passage.\nStep5: Check the length of the correct answer. If the answer is longer than all the distractors, adjust it to be more concise while retaining its meaning.\nStep6: Self-critique the question and options to ensure clarity, accuracy, and relevance. \n  - Ensure that the question is clear and unambiguous.\n  - Ensure that the correct answer is clearly the best choice.\n  - Ensure that the distractors are plausible and relevant.\n  - Ensure that all the options are similar in length, structure, tone, and complexity.\n\n\nPrint out your reasoning BEFORE you print out the mutliple-choice main idea question. \n\nIMPORTANT: \n1) Wrap up the multiple-choice main idea question within <QUESTION></QUESTION> tags. The stem SHOULD be included in the <QUESTION> tags. Example:\n<QUESTION>What is ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E25676D0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000154E31BCB40> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E0416320>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 23:56:00 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'4352'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'4358'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29998553'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'2ms'), (b'x-request-id', b'req_4eaef404cbae42e9036eb1c891f1eb39'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=QRDcMget4rehpp.wSZPX_2RArE.wYslTFROpzJFfU2k-1753314960-1.0.1.1-b1awufDTIb1wEssA2GBeNHSZsYdgx6AePpRLRc2dTKdZ2NJFdY.qjWDOj9O0TAuj0lHlvKxuP2A8aKG_ytOjPJiVyWwqYLolTiPM4K_UmIk; path=/; expires=Thu, 24-Jul-25 00:26:00 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=L2jpXs4cnoGq1yN4oK4C0jYafNouh9uy_Z20LtwsekE-1753314960793-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963f1c8d6c8327d2-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:src.mcq_generation:MCQ extracted on try 1.
# INFO:src.mcq_generation:Valid MCQ generated on try 1.
# INFO:src.mcq_generation:Answer extracted successfully.
# INFO:root:Table 'evaluation_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in evaluating the quality of multiple-choice questions generated to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to evaluate the quality of a multiple-choice question using a checklist in [CHECKLIST].\nThe user provides the multiple-choice question, the correct answer, the source text, and/or the contextual text.  \nProvide evaluation following the guidelines in [GUIDELINES].\nOutput your evaluation in the format specified in [OUTPUT FORMAT].\nself-critique your evalutation: \n  - the evaluation is based on the items in [CHECKLIST]. \n  - the evaluation follows the guidelines in [GUIDELINES].\n  - the output is in the format specified in [OUTPUT FORMAT].\n\n[CHECKLIST]\n**Content Accuracy and Quality Based on the Source Text**\n  •\tThere is only one correct answer; none of the distractors could apparently be interpreted as correct.\n  •\tDistractors are plausible misunderstandings.\n  •\tAll options are similar in tone, length, structure, and complexity, ensuring fairness and avoiding clues.\n  •\tDistractors do not use absolute terms (e.g., always, only, never, completely) unless such wording reflects a realistic but incorrect overgeneralization or misconception.\n  •\tDistractors are independent from each other and from the correct answer (i.e., not paraphrases or minor variations).\n**Language Quality**\n  •\tThe question stem has no unnecessary lead-ins like “According to the text,” “Based on the passage,” etc., unless needed for clarity, such as "According to conflict theory".\n  •\tThe question and options are clear, concise, and grammatically correct, free from redundancy and overly complex language.\n  •\tThe correct answer is not the longest among all the options.\n**Formatting Requirements**\n  •\tThe multiple-choice question should include the stem and four answer options starting with A), B), C), and D).:\n    What function did early exhibitors serve in the showcasing of movies in theaters?\n    \\nA) They determined the arrangement of different elements in the film program.\n    \\nB) They offered guidance to filmmakers regarding suitable movie content\n    \\nC) They frequently participated in live performances.\n    \\nD) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more line breaks in the question and answer options than shown in the example format.\n  •\tThe correct answer should includes both the correct option letter (e.g., A) ) and full answer text following this format:\n    D) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more space between the correct option letter and the answer text than shown in the example format.\n\n[GUIDELINES]\nStep1: Attempt to answer the multiple-choice question using the source text.\nStep2: Evaluate the question and answer choices using the checklist. \nStep3: Provide evaluation result based on the following rules. \n  - If all checklist criteria are met, output "YES".\n  - If any items under the **Content Accuracy and Quality Based on the Source Text** section is clearly and indisputably unmet, output: "NO".\n  **IMPORTANT**: Use "NO" only when there is clear and objective evidence that the criteria are not met. \n  - If all content-related criteria are met, but one or more items in either **Language Quality** or **Formatting Requirements** are not met, revise the question and/or the answer according to the criteria. Output "REVISED" followed by the revised version of the question and/or the revised answer. \n  **IMPORTANT**: Use "REVISED" only when problems are clearly and indisputably present. \nBe precise and cautious in your judgments. Do not ove ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E71AAB30>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000154E0F4E5C0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E0D65AE0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 23:56:03 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'2184'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'2188'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29998357'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'3ms'), (b'x-request-id', b'req_94d2bfff0876f90c916e1556c30d7252'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=VBSX3LydeKzKzXMEBsDPGbJ3YDI8j7S0Cbwli_rQUVo-1753314963-1.0.1.1-3nI8OtRY0U6XgIiwHe9lwfIwy5g1j5DsD3TNUJwBpZqvtMrnbq_5UXCvPJ3iJ.C13HdOPKeJHt8Ad_MfrwgtWs4sLltxVvmnS6N3kRkhcmo; path=/; expires=Thu, 24-Jul-25 00:26:03 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=LBswvDfuuS85VdwCTxIaJYUnmZ72xN4xF7E7kRLciho-1753314963204-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963f1ca96e3727d2-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'evaluation_metadata'.
# INFO:src.mcq_generation:Evaluation metadata generated successfully.
# INFO:src.mcq_generation:Evaluation passed successfully.
# INFO:root:Metadata inserted into 'mcq_metadata'.
# INFO:root:Questions generated successfully.
# INFO:root:MCQ options shuffled randomly.
# INFO:root:MCQ options shuffled successfully.
# INFO:root:Questions reformatted successfully.
# INFO:root:Table 'workflow_metadata' created or already exists.
# INFO:root:Metadata inserted into 'workflow_metadata'.
# INFO:root:Workflow metadata stored successfully.
# INFO:root:Workflow started at: 2025-07-23 16:56:03.289100
# INFO:root:Invocation ID: 561f31ff-da86-4020-a38b-91a46b4b1424
# __________________________________________Processing file 2 of 20: ..\data\History\10.4.txt___________________________________________________
# INFO:root:Text is now successfully chunked into smaller parts.
# INFO:root:Table 'plan_metadata' created or already exists.
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# ...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'plan_metadata'.
# INFO:root:Plan generated successfully.
# INFO:root:Task list created successfully.
# INFO:root:Table 'mcq_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in writing multiple-choice questions to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYou are asked to write a main idea multiple-choice question based on an academic text summary provided by the user. \nFollow the guidelines in [GUIDELINES] to do exactly what you are instructed to do. \nNOTE: The user may provide an already generated question with evaluations, in which case you should revise the provided question based on the guidelines in [GUIDELINES] and the evaluations.\n\n[DEFINITION]\n**What are main idea questions?**\nMain idea questions assess a student\'s ability to identify the central point or primary argument of a text, passage, or section.\nInstead of focusing on specific details, examples, or minor points, these questions target the big picture — what the author is fundamentally trying to convey.\n\n[GUIDELINES]\nStep1: Carefully read the TEXT to understand its main idea.  \nStep2: Write a clear question stem. Typical stems include:\n  - "Which of the following best expresses the main idea of the passage?"\n  - "What is the primary purpose of the text?"\n  - "What is the central argument of the article?"\nStep3: Create the correct answer option. \n  - It should accurately reflect the main idea.\n  - It should be broad enough to cover the whole passage but specific enough to show real understanding.\n  - It should use words that are in the question sparingly.\nStep4: Write three plausible distractors. Good distractors often:\n  - Reflect common misconceptions or misinterpretations of the text.\n  - Sound reasonable to a student who only skimmed or misunderstood the text.\n  - Independent of each other and NOT variants of the correct answer.\n  - May reflect minor details from the text.\n  - Be similar in length, structure, tone, and complexity to the correct answer.\n  - Avoid deterministic words (e.g., solely, completely, always, never, purely, every, only) unless they accurately reflect real-world absolutes\n      Many test-takers are trained to spot absolute terms in options as red flags. Using these words in distractors can weaken the item’s ability to discriminate between high- and low-performing students unless they represent a plausible yet incorrect overstatement. Do not use them simply to make distractors sound wrong or extreme.\n      **Example**: \n      What is the main idea of the passage?\n        A). Urban planning always leads to positive outcomes for all residents.(Unrealistic exaggeration)\n        B). The sole purpose of urban planning is to increase green spaces in cities.(Overgeneralization)  \n        C). Urban planning must completely eliminate inequality to be effective. (Overly absolute)\n        D). Urban planning shapes city life and balances livability, equity, and sustainability. (correct answer)\n      Note: The distractors are easily dismissed by test-wise students, regardless of whether they understood the passage.\nStep5: Check the length of the correct answer. If the answer is longer than all the distractors, adjust it to be more concise while retaining its meaning.\nStep6: Self-critique the question and options to ensure clarity, accuracy, and relevance. \n  - Ensure that the question is clear and unambiguous.\n  - Ensure that the correct answer is clearly the best choice.\n  - Ensure that the distractors are plausible and relevant.\n  - Ensure that all the options are similar in length, structure, tone, and complexity.\n\n\nPrint out your reasoning BEFORE you print out the mutliple-choice main idea question. \n\nIMPORTANT: \n1) Wrap up the multiple-choice main idea question within <QUESTION></QUESTION> tags. The stem SHOULD be included in the <QUESTION> tags. Example:\n<QUESTION>What is ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E10BDD80>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000154E10AA140> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E742D270>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 24 Jul 2025 00:02:40 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'12655'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'12671'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29998338'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'3ms'), (b'x-request-id', b'req_daeb6147b50dff41d7ad9daff82dd8ca'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=6NGWRW6X_CYNvnpA6At3a4ItmwBnsGe4O7KtDsSLODE-1753315360-1.0.1.1-731pAs33DXagxhgBRUQLpNKQgkFLkg7JSViAuB0k.teOW48_d6SieLRpevUIfQfrZSdfoSA4BuOXg3yqv1VfDWRusd1.ZxwTQj53BJ7uVDo; path=/; expires=Thu, 24-Jul-25 00:32:40 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=Ada3HxSPlni9xEj_CmD4PKCUJsliJ40AgaXdYx0CLNU-1753315360599-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963f261c1d2a27d1-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:src.mcq_generation:MCQ extracted on try 1.
# INFO:src.mcq_generation:Valid MCQ generated on try 1.
# INFO:src.mcq_generation:Answer extracted successfully.
# INFO:root:Table 'evaluation_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in evaluating the quality of multiple-choice questions generated to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to evaluate the quality of a multiple-choice question using a checklist in [CHECKLIST].\nThe user provides the multiple-choice question, the correct answer, the source text, and/or the contextual text.  \nProvide evaluation following the guidelines in [GUIDELINES].\nOutput your evaluation in the format specified in [OUTPUT FORMAT].\nself-critique your evalutation: \n  - the evaluation is based on the items in [CHECKLIST]. \n  - the evaluation follows the guidelines in [GUIDELINES].\n  - the output is in the format specified in [OUTPUT FORMAT].\n\n[CHECKLIST]\n**Content Accuracy and Quality Based on the Source Text**\n  •\tThere is only one correct answer; none of the distractors could apparently be interpreted as correct.\n  •\tDistractors are plausible misunderstandings.\n  •\tAll options are similar in tone, length, structure, and complexity, ensuring fairness and avoiding clues.\n  •\tDistractors do not use absolute terms (e.g., always, only, never, completely) unless such wording reflects a realistic but incorrect overgeneralization or misconception.\n  •\tDistractors are independent from each other and from the correct answer (i.e., not paraphrases or minor variations).\n**Language Quality**\n  •\tThe question stem has no unnecessary lead-ins like “According to the text,” “Based on the passage,” etc., unless needed for clarity, such as "According to conflict theory".\n  •\tThe question and options are clear, concise, and grammatically correct, free from redundancy and overly complex language.\n  •\tThe correct answer is not the longest among all the options.\n**Formatting Requirements**\n  •\tThe multiple-choice question should include the stem and four answer options starting with A), B), C), and D).:\n    What function did early exhibitors serve in the showcasing of movies in theaters?\n    \\nA) They determined the arrangement of different elements in the film program.\n    \\nB) They offered guidance to filmmakers regarding suitable movie content\n    \\nC) They frequently participated in live performances.\n    \\nD) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more line breaks in the question and answer options than shown in the example format.\n  •\tThe correct answer should includes both the correct option letter (e.g., A) ) and full answer text following this format:\n    D) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more space between the correct option letter and the answer text than shown in the example format.\n\n[GUIDELINES]\nStep1: Attempt to answer the multiple-choice question using the source text.\nStep2: Evaluate the question and answer choices using the checklist. \nStep3: Provide evaluation result based on the following rules. \n  - If all checklist criteria are met, output "YES".\n  - If any items under the **Content Accuracy and Quality Based on the Source Text** section is clearly and indisputably unmet, output: "NO".\n  **IMPORTANT**: Use "NO" only when there is clear and objective evidence that the criteria are not met. \n  - If all content-related criteria are met, but one or more items in either **Language Quality** or **Formatting Requirements** are not met, revise the question and/or the answer according to the criteria. Output "REVISED" followed by the revised version of the question and/or the revised answer. \n  **IMPORTANT**: Use "REVISED" only when problems are clearly and indisputably present. \nBe precise and cautious in your judgments. Do not ove ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E7179330>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000154E10AA440> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000154E742DDB0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 24 Jul 2025 00:02:46 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'5928'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'5936'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29998114'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'3ms'), (b'x-request-id', b'req_1ac6c744b3a2a611bce52fd17dbf54e0'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=vThBSvAm9xKbYsulgoqn6xBVrLgmx1FeH0BS_SC5mmI-1753315366-1.0.1.1-Gypq0fzUrVHnx69TNcMWoWKM2r6p.cZh2lCSCj2UFS6r0YLcozPAyAS_LPoou4A0q2Pkx3nWNq8BPgkh_5Jek5nliuAMS5ErGVIqvhxPXlM; path=/; expires=Thu, 24-Jul-25 00:32:46 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=kNkA4FIvrB9KFnqFW5GIs7wV67We4ZYzEutRmRtkODA-1753315366760-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963f266c49156a31-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'evaluation_metadata'.
# INFO:src.mcq_generation:Evaluation metadata generated successfully.
# INFO:src.mcq_generation:Evaluation revised successfully.
# INFO:root:Metadata inserted into 'mcq_metadata'.
# INFO:root:Questions generated successfully.
# INFO:root:MCQ options shuffled randomly.
# INFO:root:MCQ options shuffled successfully.
# INFO:root:Questions reformatted successfully.
# INFO:root:Table 'workflow_metadata' created or already exists.
# INFO:root:Metadata inserted into 'workflow_metadata'.
# INFO:root:Workflow metadata stored successfully.

# %%
from src.general import *

# %%
directory_path = '../output/mcqs/main_ideas'
output_file = '../output/mcqs/all_main_ideas.csv'

# %%
combine_csv_files(
    directory_path=directory_path,
    output_file=output_file,
)

# %%
# Create a DataFrame to store the results
mcq_data = {
    'Subject': subjects,
    'Chapter': chapter_names,
    'Section': section_names,
    'Question_type': question_types,
    'Question': mcq_list,
    'Answer': mcq_answer_list
}

mcq_df = pd.DataFrame(mcq_data)

# Ensure the output directory exists
output_directory = Path(output_directory)
output_directory.mkdir(parents=True, exist_ok=True)
output_file = output_directory / f'{subject}_mcqs.csv'

# Save the DataFrame to a CSV file
mcq_df.to_csv(output_file, index=False)

# %%
text_df = extract_texts(
    subject=subject,
    directory_path=directory_path,
    output_directory=output_directory,
)

# %%
from pathlib import Path
import re
import pandas as pd 
from src.general import *
from src.workflow import question_generation_workflow


# get files from ../data/sample_texts
files = get_files_in_directory(directory_path)
directory_path = Path(directory_path)
subjects = []
chapter_names = []
section_names = []
question_types = []
mcq_list = []
mcq_answer_list = []

for afile in files: 
    # Get chapter and section names from the file name
    file_path = Path(afile)
    # Extract relative file name (e.g., "2.1.txt")
    relative_file_name = file_path.relative_to(directory_path)
    # Remove the .txt suffix
    file_stem = relative_file_name.stem  
    # Extract chapter and section names
    try:
        chapter_name, section_name = file_stem.split('.')
    except ValueError:
        raise ValueError(f"Filename format is incorrect: '{file_stem}'. Expected format 'X.Y.txt'")
    
    # Read the afile content
    atext = read_text_file(afile)

    # Generate MCQs using the question generation workflow
    mcqs = await question_generation_workflow(atext,
                                                fact = 1, 
                                                inference = 1,
                                                main_idea = 1,
                                                model = 'gpt-4o',)
    for mcq in mcqs:
        amcq = mcq.get('mcq', 'No MCQ generated')
        amcq_answer = mcq.get('mcq_answer', 'No MCQ answer generated')

        # Remove the 'Q1: ' from the mcq and mcq_answer
        amcq = re.sub(r'^Q\d+: ', '', amcq)
        amcq_answer = re.sub(r'^Q\d+: ', '', amcq_answer)
        
        question_type = mcq.get("question_type", "unknown")

        # Append the results to the list
        question_types.append(question_type)
        mcq_list.append(amcq)
        mcq_answer_list.append(amcq_answer)

        chapter_names.append(chapter_name)
        section_names.append(section_name)
        subjects.append(subject)


# Create a DataFrame to store the results

mcq_data = {
    'Subject': subjects,
    'Chapter': chapter_names,
    'Section': section_names,
    'Question_type': question_types,
    'Question': mcq_list,
    'Answer': mcq_answer_list
}


mcq_df = pd.DataFrame(mcq_data)
# save the DataFrame to a CSV file

output_directory = Path('../output/mcqs')
output_directory.mkdir(parents=True, exist_ok=True)
output_file = output_directory / f'{subject}_mcqs.csv'

# save output_file as a csv file
mcq_df.to_csv(output_file, index=False)
# Out:
# INFO:root:Workflow started at: 2025-07-23 10:51:00.983293
# INFO:root:Invocation ID: 4baa08ae-a485-4c3b-9a75-d0e85410b99f
# INFO:root:Text is now successfully chunked into smaller parts.
# INFO:root:Table 'plan_metadata' created or already exists.
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\n  You are an experienced college instructor specializing in developing reading comprehension questions to evaluate students\' understanding of academic texts, such as textbook chapters and academic articles. You excel at identifying and selecting key facts and inferences from these texts for question development.\n\n[TASK]:\n  Your task is to summarize the academic text provided by the user and select the specified number of facts and inferences as requested by the user following the guidelines below. \n\n[Guidelines]\n  Step1: Summarize the text \n  The text is divided into chunks (as indicated by the html tags such as <chunk1></chunk1>). Summarize the content within each chunk, maintaining the chunk tags in your summary.\n\n  Step2: Identify key facts and/or inferences\n  Depending on the user’s requests, create a list of key facts and/or inferences from the academic text. The number of facts or inferences generated in this step can be more than what the user requests. \n  \n  Read the definitions below to better understand what key facts and inferences are:\n  \n  ** Key Facts**\n  Key facts are explicit pieces of information stated directly in the text. They usually reflect the main ideas, supporting details, definitions, results, or statistics that are important for understanding the author’s argument or findings.\n \n  ** Key Inferences**\n  Key inferences are logical conclusions that a reader can draw from the information in the text, even though they are not directly stated. Inferences require the reader to interpret, analyze, or synthesize information to understand implications, underlying meanings, or cause-effect relationships.\n  Characteristics:\n  - Require higher-order thinking (interpretive or inferential comprehension)\n  - Often answer the questions: why, what does this suggest, what can be concluded, what would likely happen if...\n  Example (from a sociology article):\n  "In communities with high income inequality, researchers found lower levels of trust among residents and reduced participation in civic activities."\n  Key inference: High income inequality may contribute to weakened social cohesion.\n\n  key inferences may emerge from synthesizing ideas spread across multiple sentences or paragraphs. These inferences require readers to connect concepts that are not directly adjacent in the text.\n  Example (from a Psychology Text):\n  chunk1: "...Studies show that securely attached infants tend to be more socially competent and exhibit fewer behavioral problems later in life..."\n  chunk5: "...Longitudinal research indicates that early childhood experiences with caregivers shape patterns of emotion regulation, social skills, and even academic performance into adolescence and adulthood..."\n  Key inference: Children who experience secure attachment and authoritative parenting early in life are more likely to develop strong emotional and social skills that persist into adolescence and adulthood.\n\n  **Principles for Identifying Key Facts and Inferences**\n    - Focus on Central Ideas: Identify the main argument, thesis, or purpose of the text.\n    - Highlight Supporting Information: Look for facts, evidence, definitions, or examples that directly support the main ideas.\n    - Pay Attention to Logical Relationships: Note cause-effect, comparison, contrast, and sequence relationships that organize the information.\n    - Recognize Implied Meaning: Infer what the author suggests but does not say directly—such as assumptions, tone, or implications.\n    - Ignore peripheral details: Exclude minor details (e.g., time, location), anecdotes, or examples that do not contribute significantly to the overall understanding of the text.\n    - Prioritize What’s Essential for Understanding: Choose facts and inferences that are crucial for grasping the ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x00000213163443D0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x0000021315CE56C0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021316DCE680>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 17:51:29 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'27126'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'27176'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29989510'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'20ms'), (b'x-request-id', b'req_e50dbd6cd109b0b0aee84bc2b5df7655'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=yCbuCvf0LnzrJrCgbbwISUGDflK3W_Zhi3OYi3FJEQM-1753293089-1.0.1.1-shd4y5uIuAv0GvcLe4qMMjuLs6FszF_jtDc31v7FICMGWvYgSKR24c56t0VBfqwmEikQsb1NTdCKWVPLiC4lH0DJ9i75nz44j_n9nwiTDks; path=/; expires=Wed, 23-Jul-25 18:21:29 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=adZ2HejP5TvhwMLk5.nAo9guMVNKZTCiE6LIOc1lPxI-1753293089100-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963d06047b1a27cf-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'plan_metadata'.
# INFO:root:Plan generated successfully.
# INFO:root:Task list created successfully.
# INFO:root:Table 'mcq_metadata' created or already exists.
# INFO:root:Table 'mcq_metadata' created or already exists.
# INFO:root:Table 'mcq_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in writing multiple-choice questions to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to write a factual multiple-choice question (see DEFINITION) based on a fact provided by the user. \nThis fact will be directly supported by a "source text", which is an excerpt from the academic material. \nA "contextual text" will also be provided to help you understand the broader meaning and useage of the source text. \nFollow the guidelines in [GUIDELINES] to do exactly what you are instructed to do. \nNOTE: The user may provide an already generated question with evaluations, in which case you should revise the provided question based on the guidelines in [GUIDELINES] and the evaluations.\n\n[DEFINITION]\n**What are factual questions?**\nFactual questions are those that have a single, verifiable answer based on objective information, often requiring recall of specific facts or details. \n\n[GUIDELINES]\nGenerate a multiple-choice factual question by completing the following steps in order:\n\nStep1: Based on the fact, source text, and contextual text, write a question that directly asks about the fact, avoiding unnecessary complexity. \n  - Keep the wording concise and straightforward to focus on the content.\n    Example (Good Question):\n    "What is the primary function of the amygdala?"\n    Example (Poor Question - Too Vague):\n    "What does the amygdala do?" (Too broad, unclear if asking about function, structure, or location.)\n  - Avoid unnecessary introductory phrases such as "According to the text," "Based on the source," or "According to the passage"\nStep2: Provide a correct answer to the question based on the facts in the text. The correct answer should:\n  - Be indisputably correct based on the text.\n  - Try not to use words that are in the question.\n  - Avoid wording that could make multiple answers seem correct.\nStep3: Provide three plausible distractors based on the text. The distractors should:\n  - Avoid obviously wrong or ridiculous choices.\n  - Be plausible and logically parallel but incorrect based on the text. \n  - Be similar in length, structure, tone, and complexity to the correct answer. \n  - Independent of each other and NOT variants of the correct answer.\n  - Avoid absolute terms (e.g., solely, completely, always, never, purely, every, only) unless they accurately reflect real-world absolutes\n      Many test-takers are trained to spot absolute terms in options as red flags. Using these words in distractors can weaken the item’s ability to discriminate between high- and low-performing students unless they represent a plausible yet incorrect overstatement. Do not use them simply to make distractors sound wrong or extreme.\n      Example: \n      Why is peer review important in academic research?\n      A) It ensures that every mistake is caught before publication. (Unrealistic exaggeration.)\n      B) It contributes to the credibility and validity of research. (correct answer)\n      C) It completely eliminates the risk of bias. (Overly absolute, sounds implausible.)\n      D) It allows only the best scientists to publish. (Overgeneralized and elitist; not a common misconception.)\n      The distractors are poor because they do not mirror student thinking—they simply sound extreme or silly, weakening the item\'s quality.\n  **Example with good distractors**\n    which of the following best illustrates the role of peer groups in the socialization process?\n      A) Teaching a child the formal rules of grammar and writing. (distractor)\n      B) Reinforcing cultural norms through interaction with age-mates. (correct answer)\n      C) Broadcasting societal ideals through scripted television shows. (di ...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in writing multiple-choice questions to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to write an inferential multiple-choice question (see [DEFINITION]) based on an inference provided by the user. \nThis inference will be directly supported by a "source text", which is an excerpt from the academic material. \nA "contextual text" will also be provided to help you understand the broader meaning and useage of the source text. \nFollow the guidelines in [GUIDELINES] to do exactly what you are instructed to do. \nNOTE: The user may provide an already generated question with evaluations, in which case you should revise the provided question based on the guidelines in [GUIDELINES] and the evaluations.\n\n[DEFINITION]\n**What are inferential questions?**\nInferential questions require students to go beyond the explicit information in a text and draw conclusions based on evidence, reasoning, and prior knowledge. Unlike literal questions, which ask for directly stated facts, inferential questions challenge students to interpret, analyze, or predict based on textual clues.\nFor example, \nExcerpt:\n"Studies have shown that prolonged exposure to stress can negatively impact cognitive function, particularly memory and decision-making. This is because chronic stress leads to an overproduction of cortisol, a hormone that, in excessive amounts, has been linked to neural atrophy in the hippocampus, a brain region crucial for memory formation."\nLiteral Question:\n"What is one effect of chronic stress on the brain?"\n(Answer: Neural atrophy in the hippocampus, affecting memory formation.)\nInferential Question:\n"Why might individuals in high-stress professions experience difficulty making decisions?"\n(Reasoning and Answer: The passage states that chronic stress impairs cognitive functions like decision-making. Since high-stress professions expose individuals to prolonged stress, they may experience cognitive difficulties due to excessive cortisol affecting brain regions involved in these functions.)\n\n[GUIDELINES]\nStep1: Summarize your understanding of what inferential questions are. \nStep2: Based on the inference, source text, and contextual text, write a question about the inference. \n  - Focus the question on the inference.\n  - Use clear and concise language; avoid overly complex or wordy constructions.\n  - Omit unnecessary introductory phrases such as "According to the text," "Based on the source," or "According to the passage\nStep3: Provide a correct answer to the inferential question based on the inference, the source text, and the contextual text. The correct answer should:\n  - Be indisputably correct based on the text.\n  - Try not to use words that are in the question.\n  - Avoid wording that could make multiple answers seem correct.\nStep4: Provide three plausible distractors based on the text. The distractors should:\n  - Avoid obviously wrong or ridiculous choices.\n  - Be plausible and logically parallel but incorrect based on the text. \n  - Be similar in length, structure, tone, and complexity to the correct answer. \n  - Independent of each other and NOT variants of the correct answer.\n  - Avoid deterministic words (e.g., solely, completely, always, never, purely, every, only) unless they accurately reflect real-world absolutes\n      Many test-takers are trained to spot absolute terms in options as red flags. Using these words in distractors can weaken the item’s ability to discriminate between high- and low-performing students unless they represent a plausible yet incorrect overstatement. Do not use them simply to make distractors sound wrong or extreme.\n      Example: \n      Why is peer review important in  ...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in writing multiple-choice questions to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYou are asked to write a main idea multiple-choice question based on an academic text summary provided by the user. \nFollow the guidelines in [GUIDELINES] to do exactly what you are instructed to do. \nNOTE: The user may provide an already generated question with evaluations, in which case you should revise the provided question based on the guidelines in [GUIDELINES] and the evaluations.\n\n[DEFINITION]\n**What are main idea questions?**\nMain idea questions assess a student\'s ability to identify the central point or primary argument of a text, passage, or section.\nInstead of focusing on specific details, examples, or minor points, these questions target the big picture — what the author is fundamentally trying to convey.\n\n[GUIDELINES]\nStep1: Carefully read the TEXT to understand its main idea.  \nStep2: Write a clear question stem. Typical stems include:\n  - "Which of the following best expresses the main idea of the passage?"\n  - "What is the primary purpose of the text?"\n  - "What is the central argument of the article?"\nStep3: Create the correct answer option. \n  - It should accurately reflect the main idea.\n  - It should be broad enough to cover the whole passage but specific enough to show real understanding.\n  - It should use words that are in the question sparingly.\nStep4: Write three plausible distractors. Good distractors often:\n  - Reflect common misconceptions or misinterpretations of the text.\n  - Sound reasonable to a student who only skimmed or misunderstood the text.\n  - Independent of each other and NOT variants of the correct answer.\n  - May reflect minor details from the text.\n  - Be similar in length, structure, tone, and complexity to the correct answer.\n  - Avoid deterministic words (e.g., solely, completely, always, never, purely, every, only) unless they accurately reflect real-world absolutes\n      Many test-takers are trained to spot absolute terms in options as red flags. Using these words in distractors can weaken the item’s ability to discriminate between high- and low-performing students unless they represent a plausible yet incorrect overstatement. Do not use them simply to make distractors sound wrong or extreme.\n      **Example**: \n      What is the main idea of the passage?\n        A). Urban planning always leads to positive outcomes for all residents.(Unrealistic exaggeration)\n        B). The sole purpose of urban planning is to increase green spaces in cities.(Overgeneralization)  \n        C). Urban planning must completely eliminate inequality to be effective. (Overly absolute)\n        D). Urban planning shapes city life and balances livability, equity, and sustainability. (correct answer)\n      Note: The distractors are easily dismissed by test-wise students, regardless of whether they understood the passage.\nStep5: Check the length of the correct answer. If the answer is longer than all the distractors, adjust it to be more concise while retaining its meaning.\nStep6: Self-critique the question and options to ensure clarity, accuracy, and relevance. \n  - Ensure that the question is clear and unambiguous.\n  - Ensure that the correct answer is clearly the best choice.\n  - Ensure that the distractors are plausible and relevant.\n  - Ensure that all the options are similar in length, structure, tone, and complexity.\n\n\nPrint out your reasoning BEFORE you print out the mutliple-choice main idea question. \n\nIMPORTANT: \n1) Wrap up the multiple-choice main idea question within <QUESTION></QUESTION> tags. The stem SHOULD be included in the <QUESTION> tags. Example:\n<QUESTION>What is ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021315D19990>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x0000021315AEF3C0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021315D4E770>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x0000021315AEFDC0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021315D1B250>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x0000021315CE4540> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021315D19BD0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021315D188E0>
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021315D18760>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 17:51:34 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'5525'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'5540'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29998001'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'3ms'), (b'x-request-id', b'req_7bc1f6aed7cf83fe141da8f448c3e7bb'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=exrO4.HH8VA7UCfLFZPfNRm9fBiI4PctPiO58F.QAuA-1753293094-1.0.1.1-Y7kX26YU_h.ohrO2CFYTSnFsaWkoXFOxXdC3_iKsGtv7yQFR4RnaKXhWs6TZ8b329cd_585qSTvWk.JYknITf2iHSEEUwlB.eMO4rlN.Ip8; path=/; expires=Wed, 23-Jul-25 18:21:34 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=nMIdDTJF5JQvjKovO0mCrGwc7UHaqvHiYqnEuccmG8Q-1753293094921-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963d06affb7a27c7-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:src.mcq_generation:MCQ extracted successfully.
# INFO:src.mcq_generation:Answer extracted successfully.
# INFO:root:Table 'evaluation_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in evaluating the quality of multiple-choice questions generated to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to evaluate the quality of a multiple-choice question using a checklist in [CHECKLIST].\nThe user provides the multiple-choice question, the correct answer, the source text, and/or the contextual text.  \nProvide evaluation following the guidelines in [GUIDELINES].\nOutput your evaluation in the format specified in [OUTPUT FORMAT].\nself-critique your evalutation: \n  - the evaluation is based on the items in [CHECKLIST]. \n  - the evaluation follows the guidelines in [GUIDELINES].\n  - the output is in the format specified in [OUTPUT FORMAT].\n\n[CHECKLIST]\n**Content Accuracy and Quality Based on the Source Text**\n  •\tThere is only one correct answer; none of the distractors could apparently be interpreted as correct.\n  •\tDistractors are plausible misunderstandings.\n  •\tAll options are similar in tone, length, structure, and complexity, ensuring fairness and avoiding clues.\n  •\tDistractors do not use absolute terms (e.g., always, only, never, completely) unless such wording reflects a realistic but incorrect overgeneralization or misconception.\n  •\tDistractors are independent from each other and from the correct answer (i.e., not paraphrases or minor variations).\n**Language Quality**\n  •\tThe question stem has no unnecessary lead-ins like “According to the text,” “Based on the passage,” etc., unless needed for clarity, such as "According to conflict theory".\n  •\tThe question and options are clear, concise, and grammatically correct, free from redundancy and overly complex language.\n  •\tThe correct answer is not the longest among all the options.\n**Formatting Requirements**\n  •\tThe multiple-choice question should include the stem and four answer options starting with A), B), C), and D).:\n    What function did early exhibitors serve in the showcasing of movies in theaters?\n    \\nA) They determined the arrangement of different elements in the film program.\n    \\nB) They offered guidance to filmmakers regarding suitable movie content\n    \\nC) They frequently participated in live performances.\n    \\nD) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more line breaks in the question and answer options than shown in the example format.\n  •\tThe correct answer should includes both the correct option letter (e.g., A) ) and full answer text following this format:\n    D) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more space between the correct option letter and the answer text than shown in the example format.\n\n[GUIDELINES]\nStep1: Attempt to answer the multiple-choice question using the source text.\nStep2: Evaluate the question and answer choices using the checklist. \nStep3: Provide evaluation result based on the following rules. \n  - If all checklist criteria are met, output "YES".\n  - If any items under the **Content Accuracy and Quality Based on the Source Text** section is clearly and indisputably unmet, output: "NO".\n  **IMPORTANT**: Use "NO" only when there is clear and objective evidence that the criteria are not met. \n  - If all content-related criteria are met, but one or more items in either **Language Quality** or **Formatting Requirements** are not met, revise the question and/or the answer according to the criteria. Output "REVISED" followed by the revised version of the question and/or the revised answer. \n  **IMPORTANT**: Use "REVISED" only when problems are clearly and indisputably present. \nBe precise and cautious in your judgments. Do not ove ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021315D1BD00>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x0000021315CE4A40> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021315D182B0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 17:51:39 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'9832'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'9834'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29996953'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'6ms'), (b'x-request-id', b'req_4a6bbc5ff359630f54a1755566a48678'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=MkBkiRVCYpDgjMtuME.64j_7WBe7ez3ZMsIf9Bv2J7A-1753293099-1.0.1.1-x1nuEEKkBajqvCRQHzapcak18lrdyd1eLXp9sL4peVWaGwxFPiqh4.Dm4uY9dU86dARcGSgv_u4d923R3JPdSm2KDRyz4wkob4SCLAhi4lI; path=/; expires=Wed, 23-Jul-25 18:21:39 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=qFuBU1oF.PDZ.Mx5TJjrFa0JsX28LytspF.S9qw6A08-1753293099190-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963d06afffae27d9-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:src.mcq_generation:MCQ extracted successfully.
# INFO:src.mcq_generation:Answer extracted successfully.
# INFO:root:Table 'evaluation_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in evaluating the quality of multiple-choice questions generated to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to evaluate the quality of a multiple-choice question using a checklist in [CHECKLIST].\nThe user provides the multiple-choice question, the correct answer, the source text, and/or the contextual text.  \nProvide evaluation following the guidelines in [GUIDELINES].\nOutput your evaluation in the format specified in [OUTPUT FORMAT].\nself-critique your evalutation: \n  - the evaluation is based on the items in [CHECKLIST]. \n  - the evaluation follows the guidelines in [GUIDELINES].\n  - the output is in the format specified in [OUTPUT FORMAT].\n\n[CHECKLIST]\n**Content Accuracy and Quality Based on the Source Text**\n  •\tThere is only one correct answer; none of the distractors could apparently be interpreted as correct.\n  •\tDistractors are plausible misunderstandings.\n  •\tAll options are similar in tone, length, structure, and complexity, ensuring fairness and avoiding clues.\n  •\tDistractors do not use absolute terms (e.g., always, only, never, completely) unless such wording reflects a realistic but incorrect overgeneralization or misconception.\n  •\tDistractors are independent from each other and from the correct answer (i.e., not paraphrases or minor variations).\n**Language Quality**\n  •\tThe question stem has no unnecessary lead-ins like “According to the text,” “Based on the passage,” etc., unless needed for clarity, such as "According to conflict theory".\n  •\tThe question and options are clear, concise, and grammatically correct, free from redundancy and overly complex language.\n  •\tThe correct answer is not the longest among all the options.\n**Formatting Requirements**\n  •\tThe multiple-choice question should include the stem and four answer options starting with A), B), C), and D).:\n    What function did early exhibitors serve in the showcasing of movies in theaters?\n    \\nA) They determined the arrangement of different elements in the film program.\n    \\nB) They offered guidance to filmmakers regarding suitable movie content\n    \\nC) They frequently participated in live performances.\n    \\nD) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more line breaks in the question and answer options than shown in the example format.\n  •\tThe correct answer should includes both the correct option letter (e.g., A) ) and full answer text following this format:\n    D) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more space between the correct option letter and the answer text than shown in the example format.\n\n[GUIDELINES]\nStep1: Attempt to answer the multiple-choice question using the source text.\nStep2: Evaluate the question and answer choices using the checklist. \nStep3: Provide evaluation result based on the following rules. \n  - If all checklist criteria are met, output "YES".\n  - If any items under the **Content Accuracy and Quality Based on the Source Text** section is clearly and indisputably unmet, output: "NO".\n  **IMPORTANT**: Use "NO" only when there is clear and objective evidence that the criteria are not met. \n  - If all content-related criteria are met, but one or more items in either **Language Quality** or **Formatting Requirements** are not met, revise the question and/or the answer according to the criteria. Output "REVISED" followed by the revised version of the question and/or the revised answer. \n  **IMPORTANT**: Use "REVISED" only when problems are clearly and indisputably present. \nBe precise and cautious in your judgments. Do not ove ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021315C98F40>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x0000021315CE4640> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021315C999C0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 17:51:39 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'10504'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'10510'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29996105'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'7ms'), (b'x-request-id', b'req_fd0bc52cb22e897a271fe1562f282cb0'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=AXV7.IVJOwMhBOBzmjhhzL1EC3KFi_4_6pasX53YfAQ-1753293099-1.0.1.1-yjyD_1YrdBK9B4WrQ6GN1zBy40rKIXMx_MW0bfuCiJohRgixXMcQX6Ae8yuCP_fdVvlRrKQbwy2nHozlGMx3q_YNEOTaTK2xQNNN1XiOND4; path=/; expires=Wed, 23-Jul-25 18:21:39 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=gWy8OHm1kz90YqU.jsZ0ftCk5diW9WDDSH7gyXrOYds-1753293099894-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963d06afe95b27cb-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:src.mcq_generation:MCQ extracted successfully.
# INFO:src.mcq_generation:Answer extracted successfully.
# INFO:root:Table 'evaluation_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in evaluating the quality of multiple-choice questions generated to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to evaluate the quality of a multiple-choice question using a checklist in [CHECKLIST].\nThe user provides the multiple-choice question, the correct answer, the source text, and/or the contextual text.  \nProvide evaluation following the guidelines in [GUIDELINES].\nOutput your evaluation in the format specified in [OUTPUT FORMAT].\nself-critique your evalutation: \n  - the evaluation is based on the items in [CHECKLIST]. \n  - the evaluation follows the guidelines in [GUIDELINES].\n  - the output is in the format specified in [OUTPUT FORMAT].\n\n[CHECKLIST]\n**Content Accuracy and Quality Based on the Source Text**\n  •\tThere is only one correct answer; none of the distractors could apparently be interpreted as correct.\n  •\tDistractors are plausible misunderstandings.\n  •\tAll options are similar in tone, length, structure, and complexity, ensuring fairness and avoiding clues.\n  •\tDistractors do not use absolute terms (e.g., always, only, never, completely) unless such wording reflects a realistic but incorrect overgeneralization or misconception.\n  •\tDistractors are independent from each other and from the correct answer (i.e., not paraphrases or minor variations).\n**Language Quality**\n  •\tThe question stem has no unnecessary lead-ins like “According to the text,” “Based on the passage,” etc., unless needed for clarity, such as "According to conflict theory".\n  •\tThe question and options are clear, concise, and grammatically correct, free from redundancy and overly complex language.\n  •\tThe correct answer is not the longest among all the options.\n**Formatting Requirements**\n  •\tThe multiple-choice question should include the stem and four answer options starting with A), B), C), and D).:\n    What function did early exhibitors serve in the showcasing of movies in theaters?\n    \\nA) They determined the arrangement of different elements in the film program.\n    \\nB) They offered guidance to filmmakers regarding suitable movie content\n    \\nC) They frequently participated in live performances.\n    \\nD) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more line breaks in the question and answer options than shown in the example format.\n  •\tThe correct answer should includes both the correct option letter (e.g., A) ) and full answer text following this format:\n    D) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more space between the correct option letter and the answer text than shown in the example format.\n\n[GUIDELINES]\nStep1: Attempt to answer the multiple-choice question using the source text.\nStep2: Evaluate the question and answer choices using the checklist. \nStep3: Provide evaluation result based on the following rules. \n  - If all checklist criteria are met, output "YES".\n  - If any items under the **Content Accuracy and Quality Based on the Source Text** section is clearly and indisputably unmet, output: "NO".\n  **IMPORTANT**: Use "NO" only when there is clear and objective evidence that the criteria are not met. \n  - If all content-related criteria are met, but one or more items in either **Language Quality** or **Formatting Requirements** are not met, revise the question and/or the answer according to the criteria. Output "REVISED" followed by the revised version of the question and/or the revised answer. \n  **IMPORTANT**: Use "REVISED" only when problems are clearly and indisputably present. \nBe precise and cautious in your judgments. Do not ove ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021315CA7790>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x0000021315CE40C0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021315CA7310>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 17:51:40 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'5284'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'5297'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29997717'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'4ms'), (b'x-request-id', b'req_e7c3fe3ce6906976c16654b3247631a6'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=_wlcJ9UswZ7SqZScRXEkmJBWG94u24TQ_LnrksCdFBs-1753293100-1.0.1.1-VtqGGdy_Xqmio_sQ2FMJmNze50GBq13kE4txODYSPpVzwXxvDD8CRHL4cBFvpDeX1xfjXYR2QhlZWXzIBnqXvt44tCbQ2B1wiHD4HqZU0L4; path=/; expires=Wed, 23-Jul-25 18:21:40 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=67TlrKlffTxnt06DNxh_0lHfc2vzsD9VU099ZHmCm3M-1753293100394-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963d06d3cc3527d2-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'evaluation_metadata'.
# INFO:src.mcq_generation:Evaluation metadata generated successfully.
# INFO:src.mcq_generation:Evaluation passed successfully.
# INFO:root:Metadata inserted into 'mcq_metadata'.
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 17:51:44 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'5049'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'5271'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29997144'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'5ms'), (b'x-request-id', b'req_b7e3e87a26037d534bced2767acdc945'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=A_F7jC6SS30kAEA156HDVtrYvvcrritka7NpEQKowt0-1753293104-1.0.1.1-272N16.tYaMEG9GcXwZL6vxvrK.8IbI_xK.WEkp8ePdRlTMcqHqZd6xc._ULcElp__oJ67pkJ2rla.1XbEgUFiqcquGVzD6SpefFwhf8j8I; path=/; expires=Wed, 23-Jul-25 18:21:44 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=D6pt8yuxqLvt_Bg5wLtm80x5QZL7U_nVZTLKUD.qzHo-1753293104864-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963d06ee8f9f27c9-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# ...
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 17:52:06 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'7768'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'7830'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29998572'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'2ms'), (b'x-request-id', b'req_bea165294ad0e87e5a34e50f3f5120b1'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=886QDmn1.ss_fYDNvKh0a3YBOgW1d2ux0j77LDGfLcI-1753293126-1.0.1.1-qJfFIQ6jYEmIDo4ANPcdwVCdjGqKRnLPZwoXwgTRUc9uJYPwdzNCs2IOshhQ03BupjEw7_oyO9BPFPi2LGBqxOB5U2omJNUIJTUZ0E9Gt.k; path=/; expires=Wed, 23-Jul-25 18:22:06 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=yEzARiJOFKZxMyOEeU2I71ZJ1FiPdjB5mPPeDruuTNY-1753293126730-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963d07687fa127d9-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:src.mcq_generation:MCQ extracted successfully.
# INFO:src.mcq_generation:Answer extracted successfully.
# INFO:root:Table 'evaluation_metadata' created or already exists.
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in evaluating the quality of multiple-choice questions generated to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to evaluate the quality of a multiple-choice question using a checklist in [CHECKLIST].\nThe user provides the multiple-choice question, the correct answer, the source text, and/or the contextual text.  \nProvide evaluation following the guidelines in [GUIDELINES].\nOutput your evaluation in the format specified in [OUTPUT FORMAT].\nself-critique your evalutation: \n  - the evaluation is based on the items in [CHECKLIST]. \n  - the evaluation follows the guidelines in [GUIDELINES].\n  - the output is in the format specified in [OUTPUT FORMAT].\n\n[CHECKLIST]\n**Content Accuracy and Quality Based on the Source Text**\n  •\tThere is only one correct answer; none of the distractors could apparently be interpreted as correct.\n  •\tDistractors are plausible misunderstandings.\n  •\tAll options are similar in tone, length, structure, and complexity, ensuring fairness and avoiding clues.\n  •\tDistractors do not use absolute terms (e.g., always, only, never, completely) unless such wording reflects a realistic but incorrect overgeneralization or misconception.\n  •\tDistractors are independent from each other and from the correct answer (i.e., not paraphrases or minor variations).\n**Language Quality**\n  •\tThe question stem has no unnecessary lead-ins like “According to the text,” “Based on the passage,” etc., unless needed for clarity, such as "According to conflict theory".\n  •\tThe question and options are clear, concise, and grammatically correct, free from redundancy and overly complex language.\n  •\tThe correct answer is not the longest among all the options.\n**Formatting Requirements**\n  •\tThe multiple-choice question should include the stem and four answer options starting with A), B), C), and D).:\n    What function did early exhibitors serve in the showcasing of movies in theaters?\n    \\nA) They determined the arrangement of different elements in the film program.\n    \\nB) They offered guidance to filmmakers regarding suitable movie content\n    \\nC) They frequently participated in live performances.\n    \\nD) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more line breaks in the question and answer options than shown in the example format.\n  •\tThe correct answer should includes both the correct option letter (e.g., A) ) and full answer text following this format:\n    D) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more space between the correct option letter and the answer text than shown in the example format.\n\n[GUIDELINES]\nStep1: Attempt to answer the multiple-choice question using the source text.\nStep2: Evaluate the question and answer choices using the checklist. \nStep3: Provide evaluation result based on the following rules. \n  - If all checklist criteria are met, output "YES".\n  - If any items under the **Content Accuracy and Quality Based on the Source Text** section is clearly and indisputably unmet, output: "NO".\n  **IMPORTANT**: Use "NO" only when there is clear and objective evidence that the criteria are not met. \n  - If all content-related criteria are met, but one or more items in either **Language Quality** or **Formatting Requirements** are not met, revise the question and/or the answer according to the criteria. Output "REVISED" followed by the revised version of the question and/or the revised answer. \n  **IMPORTANT**: Use "REVISED" only when problems are clearly and indisputably present. \nBe precise and cautious in your judgments. Do not ove ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021316332D10>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x0000021315CE4540> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021315D2D870>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x0000021315CE4FC0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021315CB00D0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x0000021316332A10>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 17:52:09 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'5648'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'5656'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29997640'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'4ms'), (b'x-request-id', b'req_68fea8b1dd73dec80fb843c1d06b2ddd'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=YFwcUA.E1.vBzQ10aGDfU_5g8xV1a8aMNZ0VK2navQ8-1753293129-1.0.1.1-pn9wMlhi81e8b1bNd1cMxHZU3M9ZK9EIpfKYvO.I7wfIbhnON.XOco20DlD3SctF_NclSU7keNWWcD_dbRQw23.1YjcPNCsZBzL7aF6pERg; path=/; expires=Wed, 23-Jul-25 18:22:09 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=1PNcQ2N4c1BhP2zRAHZbvWCGIxqfvVNK8yjttqplSMA-1753293129212-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963d07857ac727d9-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'evaluation_metadata'.
# INFO:src.mcq_generation:Evaluation metadata generated successfully.
# INFO:src.mcq_generation:Evaluation revised successfully.
# INFO:root:Metadata inserted into 'mcq_metadata'.
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 17:52:11 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'4581'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'4590'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29998333'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'3ms'), (b'x-request-id', b'req_db87e9b47bae7c8d78b850f6c73705a7'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=HmrYw06cRi7adzQCvcOCMlj5zoCWz7NWeKTpgaKIDQk-1753293131-1.0.1.1-TMAIg8ty14BkrSFz7_PJqvKtwnXlySNZawb4VwuQ3E0qWKwmm3piTy19hD4HLPwp5VynVrfAujHEvf9M4gxVjeb2mJ3X51yef93wahITxPg; path=/; expires=Wed, 23-Jul-25 18:22:11 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=M7zyKAHXKdTtbi2KNwstWOcUYCYl5UdjykPGH1nO30Q-1753293131565-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963d079afe2e27d7-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'evaluation_metadata'.
# INFO:src.mcq_generation:Evaluation metadata generated successfully.
# INFO:src.mcq_generation:Evaluation passed successfully.
# INFO:root:Metadata inserted into 'mcq_metadata'.
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 17:52:19 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'12912'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'12930'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29996860'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'6ms'), (b'x-request-id', b'req_35d51a8c6f1816034728dadc32fbe35e'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=1MFNp7sFLM9qpaA8xnfP5mK.198RH41JKffDWFJ5NaE-1753293139-1.0.1.1-35adJvBmZ_at.LhwK9NKK3iwOjnJmDYYREMmGy6vZXxlHj4WxsnwIfLEhcKrFGp8I..wSsJj2pFXrvo5bq04mJS_1AobPHOI9iRlnHi6x1k; path=/; expires=Wed, 23-Jul-25 18:22:19 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=tBpYao01uwtX1mX_UI01C2Q_mrG.EDl2IGLWeS5E4ZQ-1753293139899-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963d079aee1b27d2-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'evaluation_metadata'.
# INFO:src.mcq_generation:Evaluation metadata generated successfully.
# INFO:src.mcq_generation:Evaluation revised successfully.
# INFO:root:Metadata inserted into 'mcq_metadata'.
# INFO:root:Questions generated successfully.
# INFO:root:MCQ options shuffled randomly.
# INFO:root:MCQ options shuffled successfully.
# INFO:root:MCQ options shuffled randomly.
# INFO:root:MCQ options shuffled successfully.
# INFO:root:MCQ options shuffled randomly.
# INFO:root:MCQ options shuffled successfully.
# INFO:root:Questions reformatted successfully.
# INFO:root:Table 'workflow_metadata' created or already exists.
# INFO:root:Metadata inserted into 'workflow_metadata'.
# INFO:root:Workflow metadata stored successfully.

# %%
from pathlib import Path
import re
import pandas as pd 
from src.general import *
from src.workflow import question_generation_workflow

subject = "pychology"
directory_path = '../data/sample_texts'
# get files from ../data/sample_texts
files = get_files_in_directory(directory_path)
directory_path = Path(directory_path)
subjects = []
chapter_names = []
section_names = []
texts = []

for afile in files: 
    # Get chapter and section names from the file name
    file_path = Path(afile)
    # Extract relative file name (e.g., "2.1.txt")
    relative_file_name = file_path.relative_to(directory_path)
    # Remove the .txt suffix
    file_stem = relative_file_name.stem  
    # Extract chapter and section names
    try:
        chapter_name, section_name = file_stem.split('.')
    except ValueError:
        raise ValueError(f"Filename format is incorrect: '{file_stem}'. Expected format 'X.Y.txt'")
    
    # Read the afile content
    atext = read_text_file(afile)

    # Append the results to the list
    subjects.append(subject)
    chapter_names.append(chapter_name)  
    section_names.append(section_name)
    texts.append(atext)

# Create a DataFrame to store the results
text_data = {   
    'Subject': subjects,
    'Chapter': chapter_names,
    'Section': section_names,
    'Text': texts
}

text_df = pd.DataFrame(text_data)
# save the DataFrame to a CSV file
output_directory = Path('../output/texts')
output_directory.mkdir(parents=True, exist_ok=True) 
output_file = output_directory / f'{subject}_texts.csv'
# save output_file as a csv file
text_df.to_csv(output_file, index=False)

# %%
mcq_df
# Out:
#      Subject Chapter Section Question_type  \
# 0  pychology       2       1          fact
# 1  pychology       2       1     inference
# 2  pychology       2       1     main_idea
# 3  pychology       2       2          fact
# 4  pychology       2       2     inference
# 5  pychology       2       2     main_idea
#
#                                             Question  \
# 0  Which feature of surveys provides participants...
# 1  What challenge does field research face when a...
# 2  Which of the following best expresses the main...
# 3  What role do symbols play in communication wit...
# 4  How does the Sapir-Whorf hypothesis explain th...
# 5  Which of the following best expresses the main...
#
#                                               Answer
# 0              B) Anonymity provided to respondents.
# 1  C) The presence of numerous unmanageable varia...
# 2  B) The passage mainly discusses how sociologis...
# 3  B) They aid in understanding experiences by co...
# 4  B) It suggests that linguistic structures guid...
# 5  A) The passage explores how cultural elements,...

# %%
output_directory = Path('../output/mcqs')
output_directory.mkdir(parents=True, exist_ok=True)
output_file = output_directory / f'{subject}_mcqs.csv'

# %%
# save output_file as a csv file
mcq_df.to_csv(output_file, index=False)

# %%
files
# Out:
# ['../data/sample_texts\\2.1.txt', '../data/sample_texts\\2.2.txt']

# %%
for afile in files:
    text = read_text_file(afile)
    print (f"Content of {afile}:")
    print(text[:1000])  # Print the first 1000 characters of the file
# Out:
# Content of ../data/sample_texts\2.1.txt:
# Learning Objectives
# By the end of this section, you should be able to:
# •	Recall the 6 Steps of the Scientific Method
# •	Differentiate between four kinds of research methods: surveys, field research, experiments, and secondary data analysis.
# •	Explain the appropriateness of specific research approaches for specific topics.
# Sociologists examine the social world, see a problem or interesting pattern, and set out to study it. They use research methods to design a study. Planning the research design is a key step in any sociological study. Sociologists generally choose from widely used methods of social investigation: primary source data collection such as survey, participant observation, ethnography, case study, unobtrusive observations, experiment, and secondary data analysis, or use of existing sources. Every research method comes with plusses and minuses, and the topic of study strongly influences which method or methods are put to use. When you are conducting research think about the be
# Content of ../data/sample_texts\2.2.txt:
# Learning Objectives
# By the end of this section, you should be able to:
# •	Differentiate values, beliefs, and norms
# •	Explain the significance of symbols and language to a culture
# •	Explain the Sapir-Whorf hypothesis
# •	Discuss the role of social control within culture
# Values and Beliefs
# The first, and perhaps most crucial, elements of culture we will discuss are values and beliefs. Value does not mean monetary worth in sociology, but rather ideals, or principles and standards members of a culture hold in high regard. Most cultures in any society hold “knowledge” (education) in high regard. Values are deeply embedded and are critical for learning a culture’s beliefs, which are the tenets or convictions that people hold to be true. Individual cultures in a society have personal beliefs, but they also shared collective values. To illustrate the difference, U.S. citizens may believe in the American Dream—that anyone who works hard enough will be successful and wealthy. Underlying this belief

# %%
# Out:
# en_core_web_sm is already installed.

# %%
for afile in files:
    text = read_text_file(afile)
    mcq_list = await question_generation_workflow(text, 
                                            fact = 1,
                                            inference = 1,
                                            main_idea = 1,
                                            model = 'gpt-4o',)
    print(f"Generated MCQs for {afile}:")
    print(mcq_list)
# Out:
# INFO:root:Workflow started at: 2025-07-23 09:37:36.788318
# INFO:root:Invocation ID: b6760318-8f75-4a40-a547-cf41dd729fd8
# INFO:root:Text is now successfully chunked into smaller parts.
# INFO:root:Table 'plan_metadata' created or already exists.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): openaipublic.blob.core.windows.net:443
# DEBUG:urllib3.connectionpool:https://openaipublic.blob.core.windows.net:443 "GET /encodings/o200k_base.tiktoken HTTP/1.1" 200 3613922
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\n  You are an experienced college instructor specializing in developing reading comprehension questions to evaluate students\' understanding of academic texts, such as textbook chapters and academic articles. You excel at identifying and selecting key facts and inferences from these texts for question development.\n\n[TASK]:\n  Your task is to summarize the academic text provided by the user and select the specified number of facts and inferences as requested by the user following the guidelines below. \n\n[Guidelines]\n  Step1: Summarize the text \n  The text is divided into chunks (as indicated by the html tags such as <chunk1></chunk1>). Summarize the content within each chunk, maintaining the chunk tags in your summary.\n\n  Step2: Identify key facts and/or inferences\n  Depending on the user’s requests, create a list of key facts and/or inferences from the academic text. The number of facts or inferences generated in this step can be more than what the user requests. \n  \n  Read the definitions below to better understand what key facts and inferences are:\n  \n  ** Key Facts**\n  Key facts are explicit pieces of information stated directly in the text. They usually reflect the main ideas, supporting details, definitions, results, or statistics that are important for understanding the author’s argument or findings.\n \n  ** Key Inferences**\n  Key inferences are logical conclusions that a reader can draw from the information in the text, even though they are not directly stated. Inferences require the reader to interpret, analyze, or synthesize information to understand implications, underlying meanings, or cause-effect relationships.\n  Characteristics:\n  - Require higher-order thinking (interpretive or inferential comprehension)\n  - Often answer the questions: why, what does this suggest, what can be concluded, what would likely happen if...\n  Example (from a sociology article):\n  "In communities with high income inequality, researchers found lower levels of trust among residents and reduced participation in civic activities."\n  Key inference: High income inequality may contribute to weakened social cohesion.\n\n  key inferences may emerge from synthesizing ideas spread across multiple sentences or paragraphs. These inferences require readers to connect concepts that are not directly adjacent in the text.\n  Example (from a Psychology Text):\n  chunk1: "...Studies show that securely attached infants tend to be more socially competent and exhibit fewer behavioral problems later in life..."\n  chunk5: "...Longitudinal research indicates that early childhood experiences with caregivers shape patterns of emotion regulation, social skills, and even academic performance into adolescence and adulthood..."\n  Key inference: Children who experience secure attachment and authoritative parenting early in life are more likely to develop strong emotional and social skills that persist into adolescence and adulthood.\n\n  **Principles for Identifying Key Facts and Inferences**\n    - Focus on Central Ideas: Identify the main argument, thesis, or purpose of the text.\n    - Highlight Supporting Information: Look for facts, evidence, definitions, or examples that directly support the main ideas.\n    - Pay Attention to Logical Relationships: Note cause-effect, comparison, contrast, and sequence relationships that organize the information.\n    - Recognize Implied Meaning: Infer what the author suggests but does not say directly—such as assumptions, tone, or implications.\n    - Ignore peripheral details: Exclude minor details (e.g., time, location), anecdotes, or examples that do not contribute significantly to the overall understanding of the text.\n    - Prioritize What’s Essential for Understanding: Choose facts and inferences that are crucial for grasping the ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130FF04100>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000002130CD43A40> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130CFF5870>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 16:37:54 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'15473'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'15478'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29989510'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'20ms'), (b'x-request-id', b'req_f311c47bc4ae3dad0ddcb6cf43ba2cc5'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=28p5akUN6d5gfUrvRapwi.CWMYAx6aciM7ISwmVVkaQ-1753288674-1.0.1.1-jkcF8alIdO54rp6kESNwqaycsrILxAgGTkNot0up_oqbV.mZ0zsbptA6IJt9mjGN9QFalajcKSjFaqo0trHiEjArBvB9ZL_q6gExnxXna6Y; path=/; expires=Wed, 23-Jul-25 17:07:54 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=7BqGKrv9WUKAqyV59ErQFSW3PjT71oAgK81eTIYOBuA-1753288674742-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963c9a863ff827c9-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'plan_metadata'.
# INFO:root:Plan generated successfully.
# INFO:root:Task list created successfully.
# INFO:root:Table 'mcq_metadata' created or already exists.
# INFO:root:Table 'mcq_metadata' created or already exists.
# INFO:root:Table 'mcq_metadata' created or already exists.
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in writing multiple-choice questions to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to write a factual multiple-choice question (see DEFINITION) based on a fact provided by the user. \nThis fact will be directly supported by a "source text", which is an excerpt from the academic material. \nA "contextual text" will also be provided to help you understand the broader meaning and useage of the source text. \nFollow the guidelines in [GUIDELINES] to do exactly what you are instructed to do. \nNOTE: The user may provide an already generated question with evaluations, in which case you should revise the provided question based on the guidelines in [GUIDELINES] and the evaluations.\n\n[DEFINITION]\n**What are factual questions?**\nFactual questions are those that have a single, verifiable answer based on objective information, often requiring recall of specific facts or details. \n\n[GUIDELINES]\nGenerate a multiple-choice factual question by completing the following steps in order:\n\nStep1: Based on the fact, source text, and contextual text, write a question that directly asks about the fact, avoiding unnecessary complexity. \n  - Keep the wording concise and straightforward to focus on the content.\n    Example (Good Question):\n    "What is the primary function of the amygdala?"\n    Example (Poor Question - Too Vague):\n    "What does the amygdala do?" (Too broad, unclear if asking about function, structure, or location.)\n  - Avoid unnecessary introductory phrases such as "According to the text," "Based on the source," or "According to the passage"\nStep2: Provide a correct answer to the question based on the facts in the text. The correct answer should:\n  - Be indisputably correct based on the text.\n  - Try not to use words that are in the question.\n  - Avoid wording that could make multiple answers seem correct.\nStep3: Provide three plausible distractors based on the text. The distractors should:\n  - Avoid obviously wrong or ridiculous choices.\n  - Be plausible and logically parallel but incorrect based on the text. \n  - Be similar in length, structure, tone, and complexity to the correct answer. \n  - Independent of each other and NOT variants of the correct answer.\n  - Avoid absolute terms (e.g., solely, completely, always, never, purely, every, only) unless they accurately reflect real-world absolutes\n      Many test-takers are trained to spot absolute terms in options as red flags. Using these words in distractors can weaken the item’s ability to discriminate between high- and low-performing students unless they represent a plausible yet incorrect overstatement. Do not use them simply to make distractors sound wrong or extreme.\n      Example: \n      Why is peer review important in academic research?\n      A) It ensures that every mistake is caught before publication. (Unrealistic exaggeration.)\n      B) It contributes to the credibility and validity of research. (correct answer)\n      C) It completely eliminates the risk of bias. (Overly absolute, sounds implausible.)\n      D) It allows only the best scientists to publish. (Overgeneralized and elitist; not a common misconception.)\n      The distractors are poor because they do not mirror student thinking—they simply sound extreme or silly, weakening the item\'s quality.\n  **Example with good distractors**\n    which of the following best illustrates the role of peer groups in the socialization process?\n      A) Teaching a child the formal rules of grammar and writing. (distractor)\n      B) Reinforcing cultural norms through interaction with age-mates. (correct answer)\n      C) Broadcasting societal ideals through scripted television shows. (di ...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in writing multiple-choice questions to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to write an inferential multiple-choice question (see [DEFINITION]) based on an inference provided by the user. \nThis inference will be directly supported by a "source text", which is an excerpt from the academic material. \nA "contextual text" will also be provided to help you understand the broader meaning and useage of the source text. \nFollow the guidelines in [GUIDELINES] to do exactly what you are instructed to do. \nNOTE: The user may provide an already generated question with evaluations, in which case you should revise the provided question based on the guidelines in [GUIDELINES] and the evaluations.\n\n[DEFINITION]\n**What are inferential questions?**\nInferential questions require students to go beyond the explicit information in a text and draw conclusions based on evidence, reasoning, and prior knowledge. Unlike literal questions, which ask for directly stated facts, inferential questions challenge students to interpret, analyze, or predict based on textual clues.\nFor example, \nExcerpt:\n"Studies have shown that prolonged exposure to stress can negatively impact cognitive function, particularly memory and decision-making. This is because chronic stress leads to an overproduction of cortisol, a hormone that, in excessive amounts, has been linked to neural atrophy in the hippocampus, a brain region crucial for memory formation."\nLiteral Question:\n"What is one effect of chronic stress on the brain?"\n(Answer: Neural atrophy in the hippocampus, affecting memory formation.)\nInferential Question:\n"Why might individuals in high-stress professions experience difficulty making decisions?"\n(Reasoning and Answer: The passage states that chronic stress impairs cognitive functions like decision-making. Since high-stress professions expose individuals to prolonged stress, they may experience cognitive difficulties due to excessive cortisol affecting brain regions involved in these functions.)\n\n[GUIDELINES]\nStep1: Summarize your understanding of what inferential questions are. \nStep2: Based on the inference, source text, and contextual text, write a question about the inference. \n  - Focus the question on the inference.\n  - Use clear and concise language; avoid overly complex or wordy constructions.\n  - Omit unnecessary introductory phrases such as "According to the text," "Based on the source," or "According to the passage\nStep3: Provide a correct answer to the inferential question based on the inference, the source text, and the contextual text. The correct answer should:\n  - Be indisputably correct based on the text.\n  - Try not to use words that are in the question.\n  - Avoid wording that could make multiple answers seem correct.\nStep4: Provide three plausible distractors based on the text. The distractors should:\n  - Avoid obviously wrong or ridiculous choices.\n  - Be plausible and logically parallel but incorrect based on the text. \n  - Be similar in length, structure, tone, and complexity to the correct answer. \n  - Independent of each other and NOT variants of the correct answer.\n  - Avoid deterministic words (e.g., solely, completely, always, never, purely, every, only) unless they accurately reflect real-world absolutes\n      Many test-takers are trained to spot absolute terms in options as red flags. Using these words in distractors can weaken the item’s ability to discriminate between high- and low-performing students unless they represent a plausible yet incorrect overstatement. Do not use them simply to make distractors sound wrong or extreme.\n      Example: \n      Why is peer review important in  ...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in writing multiple-choice questions to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYou are asked to write a main idea multiple-choice question based on an academic text summary provided by the user. \nFollow the guidelines in [GUIDELINES] to do exactly what you are instructed to do. \nNOTE: The user may provide an already generated question with evaluations, in which case you should revise the provided question based on the guidelines in [GUIDELINES] and the evaluations.\n\n[DEFINITION]\n**What are main idea questions?**\nMain idea questions assess a student\'s ability to identify the central point or primary argument of a text, passage, or section.\nInstead of focusing on specific details, examples, or minor points, these questions target the big picture — what the author is fundamentally trying to convey.\n\n[GUIDELINES]\nStep1: Carefully read the TEXT to understand its main idea.  \nStep2: Write a clear question stem. Typical stems include:\n  - "Which of the following best expresses the main idea of the passage?"\n  - "What is the primary purpose of the text?"\n  - "What is the central argument of the article?"\nStep3: Create the correct answer option. \n  - It should accurately reflect the main idea.\n  - It should be broad enough to cover the whole passage but specific enough to show real understanding.\n  - It should use words that are in the question sparingly.\nStep4: Write three plausible distractors. Good distractors often:\n  - Reflect common misconceptions or misinterpretations of the text.\n  - Sound reasonable to a student who only skimmed or misunderstood the text.\n  - Independent of each other and NOT variants of the correct answer.\n  - May reflect minor details from the text.\n  - Be similar in length, structure, tone, and complexity to the correct answer.\n  - Avoid deterministic words (e.g., solely, completely, always, never, purely, every, only) unless they accurately reflect real-world absolutes\n      Many test-takers are trained to spot absolute terms in options as red flags. Using these words in distractors can weaken the item’s ability to discriminate between high- and low-performing students unless they represent a plausible yet incorrect overstatement. Do not use them simply to make distractors sound wrong or extreme.\n      **Example**: \n      What is the main idea of the passage?\n        A). Urban planning always leads to positive outcomes for all residents.(Unrealistic exaggeration)\n        B). The sole purpose of urban planning is to increase green spaces in cities.(Overgeneralization)  \n        C). Urban planning must completely eliminate inequality to be effective. (Overly absolute)\n        D). Urban planning shapes city life and balances livability, equity, and sustainability. (correct answer)\n      Note: The distractors are easily dismissed by test-wise students, regardless of whether they understood the passage.\nStep5: Check the length of the correct answer. If the answer is longer than all the distractors, adjust it to be more concise while retaining its meaning.\nStep6: Self-critique the question and options to ensure clarity, accuracy, and relevance. \n  - Ensure that the question is clear and unambiguous.\n  - Ensure that the correct answer is clearly the best choice.\n  - Ensure that the distractors are plausible and relevant.\n  - Ensure that all the options are similar in length, structure, tone, and complexity.\n\n\nPrint out your reasoning BEFORE you print out the mutliple-choice main idea question. \n\nIMPORTANT: \n1) Wrap up the multiple-choice main idea question within <QUESTION></QUESTION> tags. The stem SHOULD be included in the <QUESTION> tags. Example:\n<QUESTION>What is ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130CE41C30>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000002130CE57D40> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130CF239A0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000002130D52C2C0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130CF23E80>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000002130D52D8C0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130CEDCCA0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130CEDE650>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130CF230A0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 16:37:58 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'3098'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'3121'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29998297'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'3ms'), (b'x-request-id', b'req_f792042b30d7e6036502d2eea972c641'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=PyFCK7GOiRyjwKTwmjvW42hLroUz3oZ2gxlTQqaqW4Y-1753288678-1.0.1.1-PjmYGzRTSzpo9gGtTgsDa8IuO7MNiUFGNLlVRryO0OqbrUAG5e7xtU5N4L2vmPHeGoktaHX8e_fseAS8qE0g9ghABi0qn_6CfQ9jkoB48NM; path=/; expires=Wed, 23-Jul-25 17:07:58 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=xGf08zhREa4nWKz1ktAlE_2iF2QFf.10rXeBdtE1TdI-1753288678316-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963c9aea582427c9-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:src.mcq_generation:MCQ extracted successfully.
# INFO:src.mcq_generation:Answer extracted successfully.
# INFO:root:Table 'evaluation_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in evaluating the quality of multiple-choice questions generated to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to evaluate the quality of a multiple-choice question using a checklist in [CHECKLIST].\nThe user provides the multiple-choice question, the correct answer, the source text, and/or the contextual text.  \nProvide evaluation following the guidelines in [GUIDELINES].\nOutput your evaluation in the format specified in [OUTPUT FORMAT].\nself-critique your evalutation: \n  - the evaluation is based on the items in [CHECKLIST]. \n  - the evaluation follows the guidelines in [GUIDELINES].\n  - the output is in the format specified in [OUTPUT FORMAT].\n\n[CHECKLIST]\n**Content Accuracy and Quality Based on the Source Text**\n  •\tThere is only one correct answer; none of the distractors could apparently be interpreted as correct.\n  •\tDistractors are plausible misunderstandings.\n  •\tAll options are similar in tone, length, structure, and complexity, ensuring fairness and avoiding clues.\n  •\tDistractors do not use absolute terms (e.g., always, only, never, completely) unless such wording reflects a realistic but incorrect overgeneralization or misconception.\n  •\tDistractors are independent from each other and from the correct answer (i.e., not paraphrases or minor variations).\n**Language Quality**\n  •\tThe question stem has no unnecessary lead-ins like “According to the text,” “Based on the passage,” etc., unless needed for clarity, such as "According to conflict theory".\n  •\tThe question and options are clear, concise, and grammatically correct, free from redundancy and overly complex language.\n  •\tThe correct answer is not the longest among all the options.\n**Formatting Requirements**\n  •\tThe multiple-choice question should include the stem and four answer options starting with A), B), C), and D).:\n    What function did early exhibitors serve in the showcasing of movies in theaters?\n    \\nA) They determined the arrangement of different elements in the film program.\n    \\nB) They offered guidance to filmmakers regarding suitable movie content\n    \\nC) They frequently participated in live performances.\n    \\nD) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more line breaks in the question and answer options than shown in the example format.\n  •\tThe correct answer should includes both the correct option letter (e.g., A) ) and full answer text following this format:\n    D) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more space between the correct option letter and the answer text than shown in the example format.\n\n[GUIDELINES]\nStep1: Attempt to answer the multiple-choice question using the source text.\nStep2: Evaluate the question and answer choices using the checklist. \nStep3: Provide evaluation result based on the following rules. \n  - If all checklist criteria are met, output "YES".\n  - If any items under the **Content Accuracy and Quality Based on the Source Text** section is clearly and indisputably unmet, output: "NO".\n  **IMPORTANT**: Use "NO" only when there is clear and objective evidence that the criteria are not met. \n  - If all content-related criteria are met, but one or more items in either **Language Quality** or **Formatting Requirements** are not met, revise the question and/or the answer according to the criteria. Output "REVISED" followed by the revised version of the question and/or the revised answer. \n  **IMPORTANT**: Use "REVISED" only when problems are clearly and indisputably present. \nBe precise and cautious in your judgments. Do not ove ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130CF22C50>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000002130CE57EC0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130CF231C0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 16:38:02 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'3793'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'3797'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29998108'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'3ms'), (b'x-request-id', b'req_ec2025b494ae41a10c72ab0bfc129269'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=NjDym2WaSJe_lZ78j2cjucMo0YZ37EuGoeuhPjFrnZg-1753288682-1.0.1.1-kWiXSUeJ94yAHFHNzypy7ciqOKXkOrOEPe_vMmVOP.e8s0EmXwXfs6siVFcTn_HjpkcR5_e6P7jsJb6gh5dxp_zUMyRdjQ0cr3BNIKGX3GM; path=/; expires=Wed, 23-Jul-25 17:08:02 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=FjKSQgfM24b.r0igpU0bhGl407nGOlLG1O2sHUJcTzk-1753288682774-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963c9b0028e027cb-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'evaluation_metadata'.
# INFO:src.mcq_generation:Evaluation metadata generated successfully.
# INFO:src.mcq_generation:Evaluation passed successfully.
# INFO:root:Metadata inserted into 'mcq_metadata'.
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 16:38:02 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'7990'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'7993'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29997217'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'5ms'), (b'x-request-id', b'req_a2397005dba4399f2afb7b8f92d39159'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=z0W7aC.jjRViavPn85PGPYtY2b3ateQoOtTYYWHPmrU-1753288682-1.0.1.1-ZZ.FncCWxmYkL8UswIs9eTiImnleODJd90Mrj1JUbBh26KZhaMO5hdufrCxsR5hy_Z_QUz1_sUWGOQ_vcSvbxRGFeoU_lgn7q6afesjaxA0; path=/; expires=Wed, 23-Jul-25 17:08:02 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=VzePEQWQaJ4mFzZoeU.z5yxkT8A4VU_FQMLWfkH8dCw-1753288682956-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963c9aea3cf327d7-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:src.mcq_generation:MCQ extracted successfully.
# INFO:src.mcq_generation:Answer extracted successfully.
# INFO:root:Table 'evaluation_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in evaluating the quality of multiple-choice questions generated to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to evaluate the quality of a multiple-choice question using a checklist in [CHECKLIST].\nThe user provides the multiple-choice question, the correct answer, the source text, and/or the contextual text.  \nProvide evaluation following the guidelines in [GUIDELINES].\nOutput your evaluation in the format specified in [OUTPUT FORMAT].\nself-critique your evalutation: \n  - the evaluation is based on the items in [CHECKLIST]. \n  - the evaluation follows the guidelines in [GUIDELINES].\n  - the output is in the format specified in [OUTPUT FORMAT].\n\n[CHECKLIST]\n**Content Accuracy and Quality Based on the Source Text**\n  •\tThere is only one correct answer; none of the distractors could apparently be interpreted as correct.\n  •\tDistractors are plausible misunderstandings.\n  •\tAll options are similar in tone, length, structure, and complexity, ensuring fairness and avoiding clues.\n  •\tDistractors do not use absolute terms (e.g., always, only, never, completely) unless such wording reflects a realistic but incorrect overgeneralization or misconception.\n  •\tDistractors are independent from each other and from the correct answer (i.e., not paraphrases or minor variations).\n**Language Quality**\n  •\tThe question stem has no unnecessary lead-ins like “According to the text,” “Based on the passage,” etc., unless needed for clarity, such as "According to conflict theory".\n  •\tThe question and options are clear, concise, and grammatically correct, free from redundancy and overly complex language.\n  •\tThe correct answer is not the longest among all the options.\n**Formatting Requirements**\n  •\tThe multiple-choice question should include the stem and four answer options starting with A), B), C), and D).:\n    What function did early exhibitors serve in the showcasing of movies in theaters?\n    \\nA) They determined the arrangement of different elements in the film program.\n    \\nB) They offered guidance to filmmakers regarding suitable movie content\n    \\nC) They frequently participated in live performances.\n    \\nD) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more line breaks in the question and answer options than shown in the example format.\n  •\tThe correct answer should includes both the correct option letter (e.g., A) ) and full answer text following this format:\n    D) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more space between the correct option letter and the answer text than shown in the example format.\n\n[GUIDELINES]\nStep1: Attempt to answer the multiple-choice question using the source text.\nStep2: Evaluate the question and answer choices using the checklist. \nStep3: Provide evaluation result based on the following rules. \n  - If all checklist criteria are met, output "YES".\n  - If any items under the **Content Accuracy and Quality Based on the Source Text** section is clearly and indisputably unmet, output: "NO".\n  **IMPORTANT**: Use "NO" only when there is clear and objective evidence that the criteria are not met. \n  - If all content-related criteria are met, but one or more items in either **Language Quality** or **Formatting Requirements** are not met, revise the question and/or the answer according to the criteria. Output "REVISED" followed by the revised version of the question and/or the revised answer. \n  **IMPORTANT**: Use "REVISED" only when problems are clearly and indisputably present. \nBe precise and cautious in your judgments. Do not ove ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130FE48D30>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000002130CD43A40> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130FE490F0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 16:38:07 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'4140'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'4148'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29997360'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'5ms'), (b'x-request-id', b'req_6763d9883bbd7a2a8828a087a27e4517'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=pn2TRA.193bQ3KZuKCH6jlwBjjuyF0XxI7xeOpP7deg-1753288687-1.0.1.1-8RnZJ1UT7C50zItl62aK33fLFswrzwE1qwBED.4q.MfL4bJV4HyajLesULQ9FAcbP73.g6qA33oRdYjI74_nXGxoRmGjAAOnZgIWRIaXiGY; path=/; expires=Wed, 23-Jul-25 17:08:07 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=kj37nBk6lVpfD_3qjHJZ9qivdgKY7yEWtkTP.4O4Ke0-1753288687802-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963c9b1d2de327db-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'evaluation_metadata'.
# INFO:src.mcq_generation:Evaluation metadata generated successfully.
# INFO:src.mcq_generation:Evaluation passed successfully.
# INFO:root:Metadata inserted into 'mcq_metadata'.
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 16:38:11 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'16015'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'16122'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29996358'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'7ms'), (b'x-request-id', b'req_02b6299dd2930172b88cf3a50ceaee3d'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=O7NZ.xLohiLyjSqb6hjS2CEyFXKAbslqdeNGtpphi4A-1753288691-1.0.1.1-the_QseVBQRwX1_gxNe3TPdvbHxWgSFG2u8TfMomjhp58PDzvTJcFQfvfWjm6JwPK.O5Meje3SGuXcYxajrO3ldPAs4XS.oEDRALvvn2Vo4; path=/; expires=Wed, 23-Jul-25 17:08:11 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=3I95ZFTtCCxg72P5vlJQCcxjXKjHAXjJISfMVvRVl1c-1753288691599-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963c9aea4c3527dd-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:src.mcq_generation:MCQ extracted successfully.
# INFO:src.mcq_generation:Answer extracted successfully.
# INFO:root:Table 'evaluation_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in evaluating the quality of multiple-choice questions generated to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to evaluate the quality of a multiple-choice question using a checklist in [CHECKLIST].\nThe user provides the multiple-choice question, the correct answer, the source text, and/or the contextual text.  \nProvide evaluation following the guidelines in [GUIDELINES].\nOutput your evaluation in the format specified in [OUTPUT FORMAT].\nself-critique your evalutation: \n  - the evaluation is based on the items in [CHECKLIST]. \n  - the evaluation follows the guidelines in [GUIDELINES].\n  - the output is in the format specified in [OUTPUT FORMAT].\n\n[CHECKLIST]\n**Content Accuracy and Quality Based on the Source Text**\n  •\tThere is only one correct answer; none of the distractors could apparently be interpreted as correct.\n  •\tDistractors are plausible misunderstandings.\n  •\tAll options are similar in tone, length, structure, and complexity, ensuring fairness and avoiding clues.\n  •\tDistractors do not use absolute terms (e.g., always, only, never, completely) unless such wording reflects a realistic but incorrect overgeneralization or misconception.\n  •\tDistractors are independent from each other and from the correct answer (i.e., not paraphrases or minor variations).\n**Language Quality**\n  •\tThe question stem has no unnecessary lead-ins like “According to the text,” “Based on the passage,” etc., unless needed for clarity, such as "According to conflict theory".\n  •\tThe question and options are clear, concise, and grammatically correct, free from redundancy and overly complex language.\n  •\tThe correct answer is not the longest among all the options.\n**Formatting Requirements**\n  •\tThe multiple-choice question should include the stem and four answer options starting with A), B), C), and D).:\n    What function did early exhibitors serve in the showcasing of movies in theaters?\n    \\nA) They determined the arrangement of different elements in the film program.\n    \\nB) They offered guidance to filmmakers regarding suitable movie content\n    \\nC) They frequently participated in live performances.\n    \\nD) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more line breaks in the question and answer options than shown in the example format.\n  •\tThe correct answer should includes both the correct option letter (e.g., A) ) and full answer text following this format:\n    D) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more space between the correct option letter and the answer text than shown in the example format.\n\n[GUIDELINES]\nStep1: Attempt to answer the multiple-choice question using the source text.\nStep2: Evaluate the question and answer choices using the checklist. \nStep3: Provide evaluation result based on the following rules. \n  - If all checklist criteria are met, output "YES".\n  - If any items under the **Content Accuracy and Quality Based on the Source Text** section is clearly and indisputably unmet, output: "NO".\n  **IMPORTANT**: Use "NO" only when there is clear and objective evidence that the criteria are not met. \n  - If all content-related criteria are met, but one or more items in either **Language Quality** or **Formatting Requirements** are not met, revise the question and/or the answer according to the criteria. Output "REVISED" followed by the revised version of the question and/or the revised answer. \n  **IMPORTANT**: Use "REVISED" only when problems are clearly and indisputably present. \nBe precise and cautious in your judgments. Do not ove ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130CEB4F10>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000002130D52E1C0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130CEB4940>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# ...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'evaluation_metadata'.
# INFO:src.mcq_generation:Evaluation metadata generated successfully.
# INFO:src.mcq_generation:Evaluation revised successfully.
# INFO:root:Metadata inserted into 'mcq_metadata'.
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 16:38:49 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'17841'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'17843'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29996364'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'7ms'), (b'x-request-id', b'req_da7aff5a7fc8a5fd06a8dc77335a5d47'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=lmJexDMsV2VSOmVjH2XdH_.fEGhtxMdK1G5Nl_Jmjvs-1753288729-1.0.1.1-DaYz8bF5pWRDmW.uC0HRTXPra9_cQYWT8Pk92wEZg0pHnNE6kRcwBKej6uvv2sbOGiYsnXrDpCkfXoeUMjU2KIROabh1KwkBzoDqZo8EeNU; path=/; expires=Wed, 23-Jul-25 17:08:49 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=DSBa.NN2ViksxDrpIZ6VRq.vZ9YAYSli0W64LNm4NM4-1753288729991-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963c9bd2498c27c7-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:src.mcq_generation:MCQ extracted successfully.
# INFO:src.mcq_generation:Answer extracted successfully.
# INFO:root:Table 'evaluation_metadata' created or already exists.
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in evaluating the quality of multiple-choice questions generated to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to evaluate the quality of a multiple-choice question using a checklist in [CHECKLIST].\nThe user provides the multiple-choice question, the correct answer, the source text, and/or the contextual text.  \nProvide evaluation following the guidelines in [GUIDELINES].\nOutput your evaluation in the format specified in [OUTPUT FORMAT].\nself-critique your evalutation: \n  - the evaluation is based on the items in [CHECKLIST]. \n  - the evaluation follows the guidelines in [GUIDELINES].\n  - the output is in the format specified in [OUTPUT FORMAT].\n\n[CHECKLIST]\n**Content Accuracy and Quality Based on the Source Text**\n  •\tThere is only one correct answer; none of the distractors could apparently be interpreted as correct.\n  •\tDistractors are plausible misunderstandings.\n  •\tAll options are similar in tone, length, structure, and complexity, ensuring fairness and avoiding clues.\n  •\tDistractors do not use absolute terms (e.g., always, only, never, completely) unless such wording reflects a realistic but incorrect overgeneralization or misconception.\n  •\tDistractors are independent from each other and from the correct answer (i.e., not paraphrases or minor variations).\n**Language Quality**\n  •\tThe question stem has no unnecessary lead-ins like “According to the text,” “Based on the passage,” etc., unless needed for clarity, such as "According to conflict theory".\n  •\tThe question and options are clear, concise, and grammatically correct, free from redundancy and overly complex language.\n  •\tThe correct answer is not the longest among all the options.\n**Formatting Requirements**\n  •\tThe multiple-choice question should include the stem and four answer options starting with A), B), C), and D).:\n    What function did early exhibitors serve in the showcasing of movies in theaters?\n    \\nA) They determined the arrangement of different elements in the film program.\n    \\nB) They offered guidance to filmmakers regarding suitable movie content\n    \\nC) They frequently participated in live performances.\n    \\nD) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more line breaks in the question and answer options than shown in the example format.\n  •\tThe correct answer should includes both the correct option letter (e.g., A) ) and full answer text following this format:\n    D) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more space between the correct option letter and the answer text than shown in the example format.\n\n[GUIDELINES]\nStep1: Attempt to answer the multiple-choice question using the source text.\nStep2: Evaluate the question and answer choices using the checklist. \nStep3: Provide evaluation result based on the following rules. \n  - If all checklist criteria are met, output "YES".\n  - If any items under the **Content Accuracy and Quality Based on the Source Text** section is clearly and indisputably unmet, output: "NO".\n  **IMPORTANT**: Use "NO" only when there is clear and objective evidence that the criteria are not met. \n  - If all content-related criteria are met, but one or more items in either **Language Quality** or **Formatting Requirements** are not met, revise the question and/or the answer according to the criteria. Output "REVISED" followed by the revised version of the question and/or the revised answer. \n  **IMPORTANT**: Use "REVISED" only when problems are clearly and indisputably present. \nBe precise and cautious in your judgments. Do not ove ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130D0ADAB0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000002130D52E7C0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130D0AEE30>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 16:38:59 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'9202'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'9206'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29996747'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'6ms'), (b'x-request-id', b'req_d38e3ebbe7e5c1018be7cc65b29ab1e1'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=ZLE8xQcTAPsJSqPh7ODmC3Z86O9Tcl4H3RID6nbE94U-1753288739-1.0.1.1-gqFjM6vu6G.FBVVrX0dyGpAPpD86_hGlORQ.FOTJl2fh6SzntDFWovVNtXrBFVUydGO1F4sK1mmNn0ChFRZVktYIUdwP4_8yKk0cqiziXbE; path=/; expires=Wed, 23-Jul-25 17:08:59 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=v2c7tZXG1keW6d8hrl.j7n4e2VmK1fN1kYZvqtn14m4-1753288739404-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963c9c432a9427cb-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'evaluation_metadata'.
# INFO:src.mcq_generation:Evaluation metadata generated successfully.
# INFO:src.mcq_generation:Evaluation passed successfully.
# INFO:root:Metadata inserted into 'mcq_metadata'.
# INFO:root:Questions generated successfully.
# INFO:root:MCQ options shuffled randomly.
# INFO:root:MCQ options shuffled successfully.
# INFO:root:MCQ options shuffled randomly.
# INFO:root:MCQ options shuffled successfully.
# INFO:root:MCQ options shuffled randomly.
# INFO:root:MCQ options shuffled successfully.
# INFO:root:Questions reformatted successfully.
# INFO:root:Table 'workflow_metadata' created or already exists.
# INFO:root:Metadata inserted into 'workflow_metadata'.
# INFO:root:Workflow metadata stored successfully.
# Generated MCQs for ../data/sample_texts\2.2.txt:
# [{'system_prompt': '[ROLE]:\nYou are an experienced college instructor. You are an expert in writing multiple-choice questions to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to write a factual multiple-choice question (see DEFINITION) based on a fact provided by the user. \nThis fact will be directly supported by a "source text", which is an excerpt from the academic material. \nA "contextual text" will also be provided to help you understand the broader meaning and useage of the source text. \nFollow the guidelines in [GUIDELINES] to do exactly what you are instructed to do. \nNOTE: The user may provide an already generated question with evaluations, in which case you should revise the provided question based on the guidelines in [GUIDELINES] and the evaluations.\n\n[DEFINITION]\n**What are factual questions?**\nFactual questions are those that have a single, verifiable answer based on objective information, often requiring recall of specific facts or details. \n\n[GUIDELINES]\nGenerate a multiple-choice factual question by completing the following steps in order:\n\nStep1: Based on the fact, source text, and contextual text, write a question that directly asks about the fact, avoiding unnecessary complexity. \n  - Keep the wording concise and straightforward to focus on the content.\n    Example (Good Question):\n    "What is the primary function of the amygdala?"\n    Example (Poor Question - Too Vague):\n    "What does the amygdala do?" (Too broad, unclear if asking about function, structure, or location.)\n  - Avoid unnecessary introductory phrases such as "According to the text," "Based on the source," or "According to the passage"\nStep2: Provide a correct answer to the question based on the facts in the text. The correct answer should:\n  - Be indisputably correct based on the text.\n  - Try not to use words that are in the question.\n  - Avoid wording that could make multiple answers seem correct.\nStep3: Provide three plausible distractors based on the text. The distractors should:\n  - Avoid obviously wrong or ridiculous choices.\n  - Be plausible and logically parallel but incorrect based on the text. \n  - Be similar in length, structure, tone, and complexity to the correct answer. \n  - Independent of each other and NOT variants of the correct answer.\n  - Avoid absolute terms (e.g., solely, completely, always, never, purely, every, only) unless they accurately reflect real-world absolutes\n      Many test-takers are trained to spot absolute terms in options as red flags. Using these words in distractors can weaken the item’s ability to discriminate between high- and low-performing students unless they represent a plausible yet incorrect overstatement. Do not use them simply to make distractors sound wrong or extreme.\n      Example: \n      Why is peer review important in academic research?\n      A) It ensures that every mistake is caught before publication. (Unrealistic exaggeration.)\n      B) It contributes to the credibility and validity of research. (correct answer)\n      C) It completely eliminates the risk of bias. (Overly absolute, sounds implausible.)\n      D) It allows only the best scientists to publish. (Overgeneralized and elitist; not a common misconception.)\n      The distractors are poor because they do not mirror student thinking—they simply sound extreme or silly, weakening the item\'s quality.\n  **Example with good distractors**\n    which of the following best illustrates the role of peer groups in the socialization process?\n      A) Teaching a child the formal rules of grammar and writing. (distractor)\n      B) Reinforcing cultural norms through interaction with age-mates. (correct answer)\n      C) Broadcasting societal ideals through scripted television shows. (distractor)\n      D) Imposing institutional discipline through structured authority. (distractor)\nStep4: Check the length of the correct answer ...

# %%
files[0]
# Out:
# '../data/sample_texts\\2.1.txt'

# %%
files[0] = '../data/sample_texts\\2.1.txt'
directory_path = '../data/sample_texts'

import re  

file_name = re.sub(directory_path + '\\\\', '', files[0])
file_name = re.sub('.txt', '', file_name)
chapter_name = file_name.split('.')[0]
section_name = file_name.split('.')[1] 
print(chapter_name)
print(f"Processing file: {file_name}")
# Out:
# 2
# Processing file: 2.1

# %%
atext = read_text_file(files[0])
print(atext[:1000])  # Print the first 1000 characters of the
# Out:
# Learning Objectives
# By the end of this section, you should be able to:
# •	Recall the 6 Steps of the Scientific Method
# •	Differentiate between four kinds of research methods: surveys, field research, experiments, and secondary data analysis.
# •	Explain the appropriateness of specific research approaches for specific topics.
# Sociologists examine the social world, see a problem or interesting pattern, and set out to study it. They use research methods to design a study. Planning the research design is a key step in any sociological study. Sociologists generally choose from widely used methods of social investigation: primary source data collection such as survey, participant observation, ethnography, case study, unobtrusive observations, experiment, and secondary data analysis, or use of existing sources. Every research method comes with plusses and minuses, and the topic of study strongly influences which method or methods are put to use. When you are conducting research think about the be

# %%
mcqs = await question_generation_workflow(atext, 
                                            fact = 1, 
                                            inference = 1,
                                            main_idea = 1,
                                            model = 'gpt-4o',)
# Out:
# INFO:root:Workflow started at: 2025-07-23 09:42:11.978485
# INFO:root:Invocation ID: a940adbf-53fa-4b64-9140-e403b535927c
# INFO:root:Text is now successfully chunked into smaller parts.
# INFO:root:Table 'plan_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\n  You are an experienced college instructor specializing in developing reading comprehension questions to evaluate students\' understanding of academic texts, such as textbook chapters and academic articles. You excel at identifying and selecting key facts and inferences from these texts for question development.\n\n[TASK]:\n  Your task is to summarize the academic text provided by the user and select the specified number of facts and inferences as requested by the user following the guidelines below. \n\n[Guidelines]\n  Step1: Summarize the text \n  The text is divided into chunks (as indicated by the html tags such as <chunk1></chunk1>). Summarize the content within each chunk, maintaining the chunk tags in your summary.\n\n  Step2: Identify key facts and/or inferences\n  Depending on the user’s requests, create a list of key facts and/or inferences from the academic text. The number of facts or inferences generated in this step can be more than what the user requests. \n  \n  Read the definitions below to better understand what key facts and inferences are:\n  \n  ** Key Facts**\n  Key facts are explicit pieces of information stated directly in the text. They usually reflect the main ideas, supporting details, definitions, results, or statistics that are important for understanding the author’s argument or findings.\n \n  ** Key Inferences**\n  Key inferences are logical conclusions that a reader can draw from the information in the text, even though they are not directly stated. Inferences require the reader to interpret, analyze, or synthesize information to understand implications, underlying meanings, or cause-effect relationships.\n  Characteristics:\n  - Require higher-order thinking (interpretive or inferential comprehension)\n  - Often answer the questions: why, what does this suggest, what can be concluded, what would likely happen if...\n  Example (from a sociology article):\n  "In communities with high income inequality, researchers found lower levels of trust among residents and reduced participation in civic activities."\n  Key inference: High income inequality may contribute to weakened social cohesion.\n\n  key inferences may emerge from synthesizing ideas spread across multiple sentences or paragraphs. These inferences require readers to connect concepts that are not directly adjacent in the text.\n  Example (from a Psychology Text):\n  chunk1: "...Studies show that securely attached infants tend to be more socially competent and exhibit fewer behavioral problems later in life..."\n  chunk5: "...Longitudinal research indicates that early childhood experiences with caregivers shape patterns of emotion regulation, social skills, and even academic performance into adolescence and adulthood..."\n  Key inference: Children who experience secure attachment and authoritative parenting early in life are more likely to develop strong emotional and social skills that persist into adolescence and adulthood.\n\n  **Principles for Identifying Key Facts and Inferences**\n    - Focus on Central Ideas: Identify the main argument, thesis, or purpose of the text.\n    - Highlight Supporting Information: Look for facts, evidence, definitions, or examples that directly support the main ideas.\n    - Pay Attention to Logical Relationships: Note cause-effect, comparison, contrast, and sequence relationships that organize the information.\n    - Recognize Implied Meaning: Infer what the author suggests but does not say directly—such as assumptions, tone, or implications.\n    - Ignore peripheral details: Exclude minor details (e.g., time, location), anecdotes, or examples that do not contribute significantly to the overall understanding of the text.\n    - Prioritize What’s Essential for Understanding: Choose facts and inferences that are crucial for grasping the ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130CF23490>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000002130CE57EC0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130CF23460>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 16:42:25 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'13118'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'13121'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29989510'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'20ms'), (b'x-request-id', b'req_08b5d7c25c3a300b0b5ff14669e8b1d9'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=xPfts5n8lgbIvvoSDqAg_sYx2OQNW_zT4JuHNsneUxc-1753288945-1.0.1.1-Dd_bmjbF4uF4XhJz_WkrBS5blDVro2.PKzqN_NU_0UOpp6ZDudkAcYxYIycTkAdmUfbonRRUVK3OJziHKraJslcsiUc4HmPobUx3Lo1JO8g; path=/; expires=Wed, 23-Jul-25 17:12:25 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=_WRmMndoIs8V5mLwTtemfWfXn5wCi7wGMIdCPkxmwu4-1753288945838-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963ca134fee427cf-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'plan_metadata'.
# INFO:root:Plan generated successfully.
# INFO:root:Task list created successfully.
# INFO:root:Table 'mcq_metadata' created or already exists.
# INFO:root:Table 'mcq_metadata' created or already exists.
# INFO:root:Table 'mcq_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in writing multiple-choice questions to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to write a factual multiple-choice question (see DEFINITION) based on a fact provided by the user. \nThis fact will be directly supported by a "source text", which is an excerpt from the academic material. \nA "contextual text" will also be provided to help you understand the broader meaning and useage of the source text. \nFollow the guidelines in [GUIDELINES] to do exactly what you are instructed to do. \nNOTE: The user may provide an already generated question with evaluations, in which case you should revise the provided question based on the guidelines in [GUIDELINES] and the evaluations.\n\n[DEFINITION]\n**What are factual questions?**\nFactual questions are those that have a single, verifiable answer based on objective information, often requiring recall of specific facts or details. \n\n[GUIDELINES]\nGenerate a multiple-choice factual question by completing the following steps in order:\n\nStep1: Based on the fact, source text, and contextual text, write a question that directly asks about the fact, avoiding unnecessary complexity. \n  - Keep the wording concise and straightforward to focus on the content.\n    Example (Good Question):\n    "What is the primary function of the amygdala?"\n    Example (Poor Question - Too Vague):\n    "What does the amygdala do?" (Too broad, unclear if asking about function, structure, or location.)\n  - Avoid unnecessary introductory phrases such as "According to the text," "Based on the source," or "According to the passage"\nStep2: Provide a correct answer to the question based on the facts in the text. The correct answer should:\n  - Be indisputably correct based on the text.\n  - Try not to use words that are in the question.\n  - Avoid wording that could make multiple answers seem correct.\nStep3: Provide three plausible distractors based on the text. The distractors should:\n  - Avoid obviously wrong or ridiculous choices.\n  - Be plausible and logically parallel but incorrect based on the text. \n  - Be similar in length, structure, tone, and complexity to the correct answer. \n  - Independent of each other and NOT variants of the correct answer.\n  - Avoid absolute terms (e.g., solely, completely, always, never, purely, every, only) unless they accurately reflect real-world absolutes\n      Many test-takers are trained to spot absolute terms in options as red flags. Using these words in distractors can weaken the item’s ability to discriminate between high- and low-performing students unless they represent a plausible yet incorrect overstatement. Do not use them simply to make distractors sound wrong or extreme.\n      Example: \n      Why is peer review important in academic research?\n      A) It ensures that every mistake is caught before publication. (Unrealistic exaggeration.)\n      B) It contributes to the credibility and validity of research. (correct answer)\n      C) It completely eliminates the risk of bias. (Overly absolute, sounds implausible.)\n      D) It allows only the best scientists to publish. (Overgeneralized and elitist; not a common misconception.)\n      The distractors are poor because they do not mirror student thinking—they simply sound extreme or silly, weakening the item\'s quality.\n  **Example with good distractors**\n    which of the following best illustrates the role of peer groups in the socialization process?\n      A) Teaching a child the formal rules of grammar and writing. (distractor)\n      B) Reinforcing cultural norms through interaction with age-mates. (correct answer)\n      C) Broadcasting societal ideals through scripted television shows. (di ...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in writing multiple-choice questions to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to write an inferential multiple-choice question (see [DEFINITION]) based on an inference provided by the user. \nThis inference will be directly supported by a "source text", which is an excerpt from the academic material. \nA "contextual text" will also be provided to help you understand the broader meaning and useage of the source text. \nFollow the guidelines in [GUIDELINES] to do exactly what you are instructed to do. \nNOTE: The user may provide an already generated question with evaluations, in which case you should revise the provided question based on the guidelines in [GUIDELINES] and the evaluations.\n\n[DEFINITION]\n**What are inferential questions?**\nInferential questions require students to go beyond the explicit information in a text and draw conclusions based on evidence, reasoning, and prior knowledge. Unlike literal questions, which ask for directly stated facts, inferential questions challenge students to interpret, analyze, or predict based on textual clues.\nFor example, \nExcerpt:\n"Studies have shown that prolonged exposure to stress can negatively impact cognitive function, particularly memory and decision-making. This is because chronic stress leads to an overproduction of cortisol, a hormone that, in excessive amounts, has been linked to neural atrophy in the hippocampus, a brain region crucial for memory formation."\nLiteral Question:\n"What is one effect of chronic stress on the brain?"\n(Answer: Neural atrophy in the hippocampus, affecting memory formation.)\nInferential Question:\n"Why might individuals in high-stress professions experience difficulty making decisions?"\n(Reasoning and Answer: The passage states that chronic stress impairs cognitive functions like decision-making. Since high-stress professions expose individuals to prolonged stress, they may experience cognitive difficulties due to excessive cortisol affecting brain regions involved in these functions.)\n\n[GUIDELINES]\nStep1: Summarize your understanding of what inferential questions are. \nStep2: Based on the inference, source text, and contextual text, write a question about the inference. \n  - Focus the question on the inference.\n  - Use clear and concise language; avoid overly complex or wordy constructions.\n  - Omit unnecessary introductory phrases such as "According to the text," "Based on the source," or "According to the passage\nStep3: Provide a correct answer to the inferential question based on the inference, the source text, and the contextual text. The correct answer should:\n  - Be indisputably correct based on the text.\n  - Try not to use words that are in the question.\n  - Avoid wording that could make multiple answers seem correct.\nStep4: Provide three plausible distractors based on the text. The distractors should:\n  - Avoid obviously wrong or ridiculous choices.\n  - Be plausible and logically parallel but incorrect based on the text. \n  - Be similar in length, structure, tone, and complexity to the correct answer. \n  - Independent of each other and NOT variants of the correct answer.\n  - Avoid deterministic words (e.g., solely, completely, always, never, purely, every, only) unless they accurately reflect real-world absolutes\n      Many test-takers are trained to spot absolute terms in options as red flags. Using these words in distractors can weaken the item’s ability to discriminate between high- and low-performing students unless they represent a plausible yet incorrect overstatement. Do not use them simply to make distractors sound wrong or extreme.\n      Example: \n      Why is peer review important in  ...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in writing multiple-choice questions to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYou are asked to write a main idea multiple-choice question based on an academic text summary provided by the user. \nFollow the guidelines in [GUIDELINES] to do exactly what you are instructed to do. \nNOTE: The user may provide an already generated question with evaluations, in which case you should revise the provided question based on the guidelines in [GUIDELINES] and the evaluations.\n\n[DEFINITION]\n**What are main idea questions?**\nMain idea questions assess a student\'s ability to identify the central point or primary argument of a text, passage, or section.\nInstead of focusing on specific details, examples, or minor points, these questions target the big picture — what the author is fundamentally trying to convey.\n\n[GUIDELINES]\nStep1: Carefully read the TEXT to understand its main idea.  \nStep2: Write a clear question stem. Typical stems include:\n  - "Which of the following best expresses the main idea of the passage?"\n  - "What is the primary purpose of the text?"\n  - "What is the central argument of the article?"\nStep3: Create the correct answer option. \n  - It should accurately reflect the main idea.\n  - It should be broad enough to cover the whole passage but specific enough to show real understanding.\n  - It should use words that are in the question sparingly.\nStep4: Write three plausible distractors. Good distractors often:\n  - Reflect common misconceptions or misinterpretations of the text.\n  - Sound reasonable to a student who only skimmed or misunderstood the text.\n  - Independent of each other and NOT variants of the correct answer.\n  - May reflect minor details from the text.\n  - Be similar in length, structure, tone, and complexity to the correct answer.\n  - Avoid deterministic words (e.g., solely, completely, always, never, purely, every, only) unless they accurately reflect real-world absolutes\n      Many test-takers are trained to spot absolute terms in options as red flags. Using these words in distractors can weaken the item’s ability to discriminate between high- and low-performing students unless they represent a plausible yet incorrect overstatement. Do not use them simply to make distractors sound wrong or extreme.\n      **Example**: \n      What is the main idea of the passage?\n        A). Urban planning always leads to positive outcomes for all residents.(Unrealistic exaggeration)\n        B). The sole purpose of urban planning is to increase green spaces in cities.(Overgeneralization)  \n        C). Urban planning must completely eliminate inequality to be effective. (Overly absolute)\n        D). Urban planning shapes city life and balances livability, equity, and sustainability. (correct answer)\n      Note: The distractors are easily dismissed by test-wise students, regardless of whether they understood the passage.\nStep5: Check the length of the correct answer. If the answer is longer than all the distractors, adjust it to be more concise while retaining its meaning.\nStep6: Self-critique the question and options to ensure clarity, accuracy, and relevance. \n  - Ensure that the question is clear and unambiguous.\n  - Ensure that the correct answer is clearly the best choice.\n  - Ensure that the distractors are plausible and relevant.\n  - Ensure that all the options are similar in length, structure, tone, and complexity.\n\n\nPrint out your reasoning BEFORE you print out the mutliple-choice main idea question. \n\nIMPORTANT: \n1) Wrap up the multiple-choice main idea question within <QUESTION></QUESTION> tags. The stem SHOULD be included in the <QUESTION> tags. Example:\n<QUESTION>What is ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130D0C9B40>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000002130D52E9C0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130D0CAAD0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000002130D52EAC0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130D0A02B0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000002130D52EBC0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130D0AF3A0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130D0CB610>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130D0AC370>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 16:42:31 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'5010'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'5013'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29998310'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'3ms'), (b'x-request-id', b'req_d9ab2eb4ba3d3593f92a7bb839fc248c'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=_digT0Ce.0Md5cTyzS2JztFpk6u1YOl0WEd8YXYcbVU-1753288951-1.0.1.1-pHfRIFTZRWuYVIrqagh3aDOy0YIjxyj5wAf8jn.oMgRq4TVDL7eMHJUfjAPNVpi7ukKaI2pyCJochRf97zkU.NzdhFdqBYEacAkie3Vp94A; path=/; expires=Wed, 23-Jul-25 17:12:31 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=FlZaCJpmzkg78zO7gTVoBxlE2MNIGJyL8KHXKAi5d8I-1753288951086-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963ca1885fbf27d7-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:src.mcq_generation:MCQ extracted successfully.
# INFO:src.mcq_generation:Answer extracted successfully.
# INFO:root:Table 'evaluation_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in evaluating the quality of multiple-choice questions generated to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to evaluate the quality of a multiple-choice question using a checklist in [CHECKLIST].\nThe user provides the multiple-choice question, the correct answer, the source text, and/or the contextual text.  \nProvide evaluation following the guidelines in [GUIDELINES].\nOutput your evaluation in the format specified in [OUTPUT FORMAT].\nself-critique your evalutation: \n  - the evaluation is based on the items in [CHECKLIST]. \n  - the evaluation follows the guidelines in [GUIDELINES].\n  - the output is in the format specified in [OUTPUT FORMAT].\n\n[CHECKLIST]\n**Content Accuracy and Quality Based on the Source Text**\n  •\tThere is only one correct answer; none of the distractors could apparently be interpreted as correct.\n  •\tDistractors are plausible misunderstandings.\n  •\tAll options are similar in tone, length, structure, and complexity, ensuring fairness and avoiding clues.\n  •\tDistractors do not use absolute terms (e.g., always, only, never, completely) unless such wording reflects a realistic but incorrect overgeneralization or misconception.\n  •\tDistractors are independent from each other and from the correct answer (i.e., not paraphrases or minor variations).\n**Language Quality**\n  •\tThe question stem has no unnecessary lead-ins like “According to the text,” “Based on the passage,” etc., unless needed for clarity, such as "According to conflict theory".\n  •\tThe question and options are clear, concise, and grammatically correct, free from redundancy and overly complex language.\n  •\tThe correct answer is not the longest among all the options.\n**Formatting Requirements**\n  •\tThe multiple-choice question should include the stem and four answer options starting with A), B), C), and D).:\n    What function did early exhibitors serve in the showcasing of movies in theaters?\n    \\nA) They determined the arrangement of different elements in the film program.\n    \\nB) They offered guidance to filmmakers regarding suitable movie content\n    \\nC) They frequently participated in live performances.\n    \\nD) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more line breaks in the question and answer options than shown in the example format.\n  •\tThe correct answer should includes both the correct option letter (e.g., A) ) and full answer text following this format:\n    D) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more space between the correct option letter and the answer text than shown in the example format.\n\n[GUIDELINES]\nStep1: Attempt to answer the multiple-choice question using the source text.\nStep2: Evaluate the question and answer choices using the checklist. \nStep3: Provide evaluation result based on the following rules. \n  - If all checklist criteria are met, output "YES".\n  - If any items under the **Content Accuracy and Quality Based on the Source Text** section is clearly and indisputably unmet, output: "NO".\n  **IMPORTANT**: Use "NO" only when there is clear and objective evidence that the criteria are not met. \n  - If all content-related criteria are met, but one or more items in either **Language Quality** or **Formatting Requirements** are not met, revise the question and/or the answer according to the criteria. Output "REVISED" followed by the revised version of the question and/or the revised answer. \n  **IMPORTANT**: Use "REVISED" only when problems are clearly and indisputably present. \nBe precise and cautious in your judgments. Do not ove ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130D0C0160>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000002130D52E740> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130D0C3A30>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 16:42:31 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'5585'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'5594'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29997255'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'5ms'), (b'x-request-id', b'req_b0fb06fff3b2fa93e731d93e19dc4256'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=sgddaOStqVjl89TsCwVdvkMIRrvhH3vhCSSqO_jz.zM-1753288951-1.0.1.1-o9MJadaQQ_ZdwaoGzXM8K8Cr8mcrNwv9IDLH4ZviObXQIZdqUg3vZH_qOcq7GBmvpqYyXNIuOG1XS3qSG514zfNfXcnuoRa4MZGqNcZ_PUM; path=/; expires=Wed, 23-Jul-25 17:12:31 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=oo.pU_Grk..4zYmuWukD3B1kN8FI5V2TsxOrlAxp0EA-1753288951626-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963ca1884f8427d3-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:src.mcq_generation:MCQ extracted successfully.
# INFO:src.mcq_generation:Answer extracted successfully.
# INFO:root:Table 'evaluation_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in evaluating the quality of multiple-choice questions generated to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to evaluate the quality of a multiple-choice question using a checklist in [CHECKLIST].\nThe user provides the multiple-choice question, the correct answer, the source text, and/or the contextual text.  \nProvide evaluation following the guidelines in [GUIDELINES].\nOutput your evaluation in the format specified in [OUTPUT FORMAT].\nself-critique your evalutation: \n  - the evaluation is based on the items in [CHECKLIST]. \n  - the evaluation follows the guidelines in [GUIDELINES].\n  - the output is in the format specified in [OUTPUT FORMAT].\n\n[CHECKLIST]\n**Content Accuracy and Quality Based on the Source Text**\n  •\tThere is only one correct answer; none of the distractors could apparently be interpreted as correct.\n  •\tDistractors are plausible misunderstandings.\n  •\tAll options are similar in tone, length, structure, and complexity, ensuring fairness and avoiding clues.\n  •\tDistractors do not use absolute terms (e.g., always, only, never, completely) unless such wording reflects a realistic but incorrect overgeneralization or misconception.\n  •\tDistractors are independent from each other and from the correct answer (i.e., not paraphrases or minor variations).\n**Language Quality**\n  •\tThe question stem has no unnecessary lead-ins like “According to the text,” “Based on the passage,” etc., unless needed for clarity, such as "According to conflict theory".\n  •\tThe question and options are clear, concise, and grammatically correct, free from redundancy and overly complex language.\n  •\tThe correct answer is not the longest among all the options.\n**Formatting Requirements**\n  •\tThe multiple-choice question should include the stem and four answer options starting with A), B), C), and D).:\n    What function did early exhibitors serve in the showcasing of movies in theaters?\n    \\nA) They determined the arrangement of different elements in the film program.\n    \\nB) They offered guidance to filmmakers regarding suitable movie content\n    \\nC) They frequently participated in live performances.\n    \\nD) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more line breaks in the question and answer options than shown in the example format.\n  •\tThe correct answer should includes both the correct option letter (e.g., A) ) and full answer text following this format:\n    D) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more space between the correct option letter and the answer text than shown in the example format.\n\n[GUIDELINES]\nStep1: Attempt to answer the multiple-choice question using the source text.\nStep2: Evaluate the question and answer choices using the checklist. \nStep3: Provide evaluation result based on the following rules. \n  - If all checklist criteria are met, output "YES".\n  - If any items under the **Content Accuracy and Quality Based on the Source Text** section is clearly and indisputably unmet, output: "NO".\n  **IMPORTANT**: Use "NO" only when there is clear and objective evidence that the criteria are not met. \n  - If all content-related criteria are met, but one or more items in either **Language Quality** or **Formatting Requirements** are not met, revise the question and/or the answer according to the criteria. Output "REVISED" followed by the revised version of the question and/or the revised answer. \n  **IMPORTANT**: Use "REVISED" only when problems are clearly and indisputably present. \nBe precise and cautious in your judgments. Do not ove ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130D0C3DC0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000002130D52EE40> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130D0AE980>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 16:42:35 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'3625'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'3682'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29997401'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'5ms'), (b'x-request-id', b'req_7d01dcdc8f68edb95f43ebd4a7665b64'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=kmltuJ1bSvQ_KwArZcHeTtJxJTgY6sAUu74sVS_K8Cg-1753288955-1.0.1.1-CLwcji_qaOn97hydFqHJiq397Hm9U_.wEjAQ9rIySSjIIJl49KDhL_ldpRYQsdghKNqtQGx_Mdl2ulRy_mYi9h.q4dGuLJ.ungA4G0zB5yo; path=/; expires=Wed, 23-Jul-25 17:12:35 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=kR2uQGxpOARh.4VYNy67sD.GfQ2sk2EcrQOwm.cu6OM-1753288955479-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963ca1ac3cca27d1-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'evaluation_metadata'.
# INFO:src.mcq_generation:Evaluation metadata generated successfully.
# INFO:src.mcq_generation:Evaluation passed successfully.
# INFO:root:Metadata inserted into 'mcq_metadata'.
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 16:42:36 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'5354'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'5371'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29998109'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'3ms'), (b'x-request-id', b'req_3c2ea64f99470ea8ad1e264878d2a129'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=0lTh.GDpOczqw2f21mlRncCxelgQy7fvC7qIKVlNgxc-1753288956-1.0.1.1-kzEhTUsyZfij7HTSDYQ1Hh6quxA7evTbFQFpKvt5RKDUqzbYc84zPMQtBuW3u2UOPjzNEnb9dU5V1ybtnvn21YyBAo1ykAfbvZWxr9jKuxE; path=/; expires=Wed, 23-Jul-25 17:12:36 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=En9wl4gApzT30ZksjPJhW6iz4AeYAJ7Qo5ZdKGKYcYk-1753288956592-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963ca1a8df676a30-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'evaluation_metadata'.
# INFO:src.mcq_generation:Evaluation metadata generated successfully.
# INFO:src.mcq_generation:Evaluation revised successfully.
# INFO:root:Metadata inserted into 'mcq_metadata'.
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 16:42:52 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'26081'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'26089'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29995578'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'8ms'), (b'x-request-id', b'req_b24ecd68b42fdb0f9052fe89c12a275d'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=vrkn4V_.Ajox8XPjv_IEJFkslwsdxtD5kZxAKh1dyls-1753288972-1.0.1.1-0jorhMta5zD4tS.pU1kr1XeqSewtlh3YHIDVvTj9blT0kabMhD1kWYNWjjiy6LF6bPM3pi1N4P3px1pFvij_SQT86wWtrQ9CjVCvMgR5pTs; path=/; expires=Wed, 23-Jul-25 17:12:52 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=0hsuYCmhnDhJJrzD8RRXcZOZVM8Z0CiXD0TzXAh8tZ4-1753288972139-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963ca188699027dd-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:src.mcq_generation:MCQ extracted successfully.
# INFO:src.mcq_generation:Answer extracted successfully.
# INFO:root:Table 'evaluation_metadata' created or already exists.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '[ROLE]:\nYou are an experienced college instructor. You are an expert in evaluating the quality of multiple-choice questions generated to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYour task is to evaluate the quality of a multiple-choice question using a checklist in [CHECKLIST].\nThe user provides the multiple-choice question, the correct answer, the source text, and/or the contextual text.  \nProvide evaluation following the guidelines in [GUIDELINES].\nOutput your evaluation in the format specified in [OUTPUT FORMAT].\nself-critique your evalutation: \n  - the evaluation is based on the items in [CHECKLIST]. \n  - the evaluation follows the guidelines in [GUIDELINES].\n  - the output is in the format specified in [OUTPUT FORMAT].\n\n[CHECKLIST]\n**Content Accuracy and Quality Based on the Source Text**\n  •\tThere is only one correct answer; none of the distractors could apparently be interpreted as correct.\n  •\tDistractors are plausible misunderstandings.\n  •\tAll options are similar in tone, length, structure, and complexity, ensuring fairness and avoiding clues.\n  •\tDistractors do not use absolute terms (e.g., always, only, never, completely) unless such wording reflects a realistic but incorrect overgeneralization or misconception.\n  •\tDistractors are independent from each other and from the correct answer (i.e., not paraphrases or minor variations).\n**Language Quality**\n  •\tThe question stem has no unnecessary lead-ins like “According to the text,” “Based on the passage,” etc., unless needed for clarity, such as "According to conflict theory".\n  •\tThe question and options are clear, concise, and grammatically correct, free from redundancy and overly complex language.\n  •\tThe correct answer is not the longest among all the options.\n**Formatting Requirements**\n  •\tThe multiple-choice question should include the stem and four answer options starting with A), B), C), and D).:\n    What function did early exhibitors serve in the showcasing of movies in theaters?\n    \\nA) They determined the arrangement of different elements in the film program.\n    \\nB) They offered guidance to filmmakers regarding suitable movie content\n    \\nC) They frequently participated in live performances.\n    \\nD) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more line breaks in the question and answer options than shown in the example format.\n  •\tThe correct answer should includes both the correct option letter (e.g., A) ) and full answer text following this format:\n    D) They created and pre-recorded the content displayed in theaters.\n  **IMPORTANT**: It is fine if there is more space between the correct option letter and the answer text than shown in the example format.\n\n[GUIDELINES]\nStep1: Attempt to answer the multiple-choice question using the source text.\nStep2: Evaluate the question and answer choices using the checklist. \nStep3: Provide evaluation result based on the following rules. \n  - If all checklist criteria are met, output "YES".\n  - If any items under the **Content Accuracy and Quality Based on the Source Text** section is clearly and indisputably unmet, output: "NO".\n  **IMPORTANT**: Use "NO" only when there is clear and objective evidence that the criteria are not met. \n  - If all content-related criteria are met, but one or more items in either **Language Quality** or **Formatting Requirements** are not met, revise the question and/or the answer according to the criteria. Output "REVISED" followed by the revised version of the question and/or the revised answer. \n  **IMPORTANT**: Use "REVISED" only when problems are clearly and indisputably present. \nBe precise and cautious in your judgments. Do not ove ...
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130D0AC610>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000002130D52C540> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000002130CEB4400>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Jul 2025 16:43:00 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'asu-knowledge-enterprise'), (b'openai-processing-ms', b'7759'), (b'openai-project', b'proj_SF1TFaZgnnT8gRH964stqZdg'), (b'openai-version', b'2020-10-01'), (b'x-envoy-upstream-service-time', b'7794'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'30000000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'29995958'), (b'x-ratelimit-reset-requests', b'6ms'), (b'x-ratelimit-reset-tokens', b'8ms'), (b'x-request-id', b'req_a966abcbb5ba47797803d9eabf60b378'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=0nf13zUVwz9e1KzvWWJxrSms6kf1ccTrUrx16X_ek.Q-1753288980-1.0.1.1-XtjoQCc6PNRTWL_wgbKbk1dw9BN9lMQgG3JOUEdGWgy5TeYB1iFV02jH9PwWXcnapVC0HZuYWiVjuSPIKhgvyVmbJNz.oX_1Lcv30IU5fFE; path=/; expires=Wed, 23-Jul-25 17:13:00 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=fKaq_jZbcK36cttJRLpWBa1THfatKEzv6AfAfuLj92E-1753288980131-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'963ca22c791627c7-SAN'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# INFO:root:Metadata inserted into 'evaluation_metadata'.
# INFO:src.mcq_generation:Evaluation metadata generated successfully.
# INFO:src.mcq_generation:Evaluation passed successfully.
# INFO:root:Metadata inserted into 'mcq_metadata'.
# INFO:root:Questions generated successfully.
# INFO:root:MCQ options shuffled randomly.
# INFO:root:MCQ options shuffled successfully.
# INFO:root:MCQ options shuffled randomly.
# INFO:root:MCQ options shuffled successfully.
# INFO:root:MCQ options shuffled randomly.
# WARNING:root:Warning: Closest match has a distance of 13, which might indicate a mismatch.
# INFO:root:MCQ options shuffled successfully.
# INFO:root:Questions reformatted successfully.
# INFO:root:Table 'workflow_metadata' created or already exists.
# INFO:root:Metadata inserted into 'workflow_metadata'.
# INFO:root:Workflow metadata stored successfully.

# %%
mcqs[0].keys()
# Out:
# dict_keys(['system_prompt', 'user_prompt', 'model', 'completion', 'execution_time', 'input_tokens', 'output_tokens', 'question_type', 'invocation_id', 'chunk', 'attempt', 'mcq', 'mcq_answer', 'timestamp'])

# %%
mcqs[0].get('mcq', 'No MCQ generated')
# Out:
# "Q1: What is the main purpose of conducting surveys in sociological research?\n\nA) Surveys are primarily used to increase television program ratings.\n\nB) Surveys are designed to observe real-time social interactions in natural settings.\n\nC) Surveys collect information on people's behaviors and opinions.\n\nD) Surveys focus solely on gathering qualitative data."

# %%
mcqs[0].get('mcq', 'No MCQ generated')

# %%
mcqs[0].get('mcq_answer', 'No MCQ answer generated')
# Out:
# "Q1: C) Surveys collect information on people's behaviors and opinions."

# %%
# A regular expression to remove the 'Q1: ' from the mcq and mcq_answer
import re   
mcqs[0]['mcq'] = re.sub(r'^Q\d+: ', '', mcqs[0]['mcq'])
mcqs[0]['mcq_answer'] = re.sub(r'^Q\d+: ', '', mcqs[0]['mcq_answer'])

# %%
mcqs[0]['mcq']
# Out:
# "What is the main purpose of conducting surveys in sociological research?\n\nA) Surveys are primarily used to increase television program ratings.\n\nB) Surveys are designed to observe real-time social interactions in natural settings.\n\nC) Surveys collect information on people's behaviors and opinions.\n\nD) Surveys focus solely on gathering qualitative data."

# %%
mcqs[0]['mcq_answer']
# Out:
# "C) Surveys collect information on people's behaviors and opinions."

# %%
{'system_prompt': '[ROLE]:\nYou are an experienced college instructor. You are an expert in writing multiple-choice questions to assess students’ understanding of academic texts (e.g., chapters in textbooks, academic articles).\n\n[TASK]:\nYou are asked to write a main idea multiple-choice question based on an academic text summary provided by the user. \nFollow the guidelines in [GUIDELINES] to do exactly what you are instructed to do. \nNOTE: The user may provide an already generated question with evaluations, in which case you should revise the provided question based on the guidelines in [GUIDELINES] and the evaluations.\n\n[DEFINITION]\n**What are main idea questions?**\nMain idea questions assess a student\'s ability to identify the central point or primary argument of a text, passage, or section.\nInstead of focusing on specific details, examples, or minor points, these questions target the big picture — what the author is fundamentally trying to convey.\n\n[GUIDELINES]\nStep1: Carefully read the TEXT to understand its main idea.  \nStep2: Write a clear question stem. Typical stems include:\n  - "Which of the following best expresses the main idea of the passage?"\n  - "What is the primary purpose of the text?"\n  - "What is the central argument of the article?"\nStep3: Create the correct answer option. \n  - It should accurately reflect the main idea.\n  - It should be broad enough to cover the whole passage but specific enough to show real understanding.\n  - It should use words that are in the question sparingly.\nStep4: Write three plausible distractors. Good distractors often:\n  - Reflect common misconceptions or misinterpretations of the text.\n  - Sound reasonable to a student who only skimmed or misunderstood the text.\n  - Independent of each other and NOT variants of the correct answer.\n  - May reflect minor details from the text.\n  - Be similar in length, structure, tone, and complexity to the correct answer.\n  - Avoid deterministic words (e.g., solely, completely, always, never, purely, every, only) unless they accurately reflect real-world absolutes\n      Many test-takers are trained to spot absolute terms in options as red flags. Using these words in distractors can weaken the item’s ability to discriminate between high- and low-performing students unless they represent a plausible yet incorrect overstatement. Do not use them simply to make distractors sound wrong or extreme.\n      **Example**: \n      What is the main idea of the passage?\n        A). Urban planning always leads to positive outcomes for all residents.(Unrealistic exaggeration)\n        B). The sole purpose of urban planning is to increase green spaces in cities.(Overgeneralization)  \n        C). Urban planning must completely eliminate inequality to be effective. (Overly absolute)\n        D). Urban planning shapes city life and balances livability, equity, and sustainability. (correct answer)\n      Note: The distractors are easily dismissed by test-wise students, regardless of whether they understood the passage.\nStep5: Check the length of the correct answer. If the answer is longer than all the distractors, adjust it to be more concise while retaining its meaning.\nStep6: Self-critique the question and options to ensure clarity, accuracy, and relevance. \n  - Ensure that the question is clear and unambiguous.\n  - Ensure that the correct answer is clearly the best choice.\n  - Ensure that the distractors are plausible and relevant.\n  - Ensure that all the options are similar in length, structure, tone, and complexity.\n\n\nPrint out your reasoning BEFORE you print out the mutliple-choice main idea question. \n\nIMPORTANT: \n1) Wrap up the multiple-choice main idea question within <QUESTION></QUESTION> tags. The stem SHOULD be included in the <QUESTION> tags. Example:\n<QUESTION>What is the main idea of the passage?\n  \\nA) Remote work has recently become more common because of its benefits to companies.\n  \\nB) Remote work is better than working in an office.\n  \\nC) Most companies now require employees to work remotely.\n  \\nD) Remote work only benefits employees, not companies.</QUESTION>\n2) Wrap up the correct answer within <ANSWER></ANSWER> tags. The answer should contain the letter of the correct answer (A, B, C, or D) and the text of the correct answer. Example:\n<ANSWER>A) Remote work has recently become more common because of its benefits to companies.</ANSWER>\n', 'user_prompt': '<text>\nThe section outlines learning objectives for understanding the geographical and cultural context of West Africa, highlighting the significance of Islam, the diversity of the region, and the social and political structures that dominated pre-colonial West Africa. It describes how Islam spread across the region, influencing trade and political dynamics, and notes the different agricultural practices and social structures of West African societies.This section describes the rise of major African empires such as Ghana, Mali, and Songhay, emphasizing their political and economic power, particularly through control of trade routes. It also covers the role and development of slavery within these empires, illustrating various forms of servitude and highlighting how Islamic influences expanded the slave trade beyond Africa.The text discusses how the European slave trade developed, focusing on the role of Portugal and other European countries in expanding the demand for enslaved Africans. It shows how slavery evolved into a race-based system in the New World, with significant impacts on African societies and a lasting legacy in the Americas.\n</text>', 'model': 'gpt-4o', 'completion': 'Reasoning:\n\nStep 1: After reviewing the provided text, the main idea revolves around the historical and cultural dynamics of pre-colonial and colonial West Africa. The text highlights the role of Islam, trade, political and social structures, and the development of slavery within African empires, and how European interests expanded the slave trade and its effects.\n\nStep 2: Writing the question stem, I will ask about the overall theme or purpose of the passage.\n\nStep 3: The correct answer needs to encapsulate the broad overview of West African history, the rise of empires, the influence of Islam, and the evolution of slavery due to European involvement.\n\nStep 4: Distractors need to misdirect by focusing on isolated details or suggest incorrect interpretations, but remain plausible.\n\nStep 5: Check that the correct answer is not significantly longer than the distractors.\n\nStep 6: Review all components to ensure clarity and accuracy.\n\n<QUESTION>What is the main idea of the passage?\n  \\nA) The achievements of West African rulers in expanding their territories.\n  \\nB) The diverse agricultural practices that sustained West African societies.\n  \\nC) The historical development and importance of West Africa, with a focus on Islam, trade, and the evolution of slavery.\n  \\nD) The exclusive impact of European colonization on West African political systems.</QUESTION>\n\n<ANSWER>C) The historical development and importance of West Africa, with a focus on Islam, trade, and the evolution of slavery.</ANSWER>', 
 'execution_time': '0:00:07.636565', 
 'input_tokens': 1114, 
 'output_tokens': 307, 
 'question_type': 'main_idea', 
 'invocation_id': '403f565a-14c7-47e3-a06c-52d20c5c9b5a', 
 'chunk': '[]', 
 'attempt': 1, 
 'mcq': 'What is the main idea of the passage regarding the historical context of West Africa?', 
 'mcq_answer': 'C) The historical development and importance of West Africa, with a focus on Islam, trade, and the evolution of slavery.', 'timestamp': '2025-07-23T16:50:02.519381'}
